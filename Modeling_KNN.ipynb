# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from scipy.sparse import csr_matrix

# %%
#notify me when a long running cell is complete
# %load_ext jupyternotify
import time

# %%
data = pd.read_csv('data/final_df.csv')
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#     mid  cust_id  rating      r_date  r_year  r_fiscQ  m_decade  m_avg_rating
# 0  3113   510180     3.0  1999-12-12    1999        4         4      3.187192  \
# 1  3113  1589382     4.0  2000-03-11    2000        1         4      3.187192
# 2  3113  1878798     2.0  2000-08-08    2000        3         4      3.187192
# 3  3113  1259176     4.0  2000-11-10    2000        4         4      3.187192
# 4  3113   873369     3.0  2000-11-20    2000        4         4      3.187192
#
#    m_quality
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   mid           1000000 non-null  int64
#  1   cust_id       1000000 non-null  int64
#  2   rating        1000000 non-null  float64
#  3   r_date        1000000 non-null  object
#  4   r_year        1000000 non-null  int64
#  5   r_fiscQ       1000000 non-null  int64
#  6   m_decade      1000000 non-null  int64
#  7   m_avg_rating  1000000 non-null  float64
#  8   m_quality     1000000 non-null  int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 68.7+ MB

# %%
data['r_date'] = data['r_date'].astype('datetime64[ns]')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   mid           1000000 non-null  int64
#  1   cust_id       1000000 non-null  int64
#  2   rating        1000000 non-null  float64
#  3   r_date        1000000 non-null  datetime64[ns]
#  4   r_year        1000000 non-null  int64
#  5   r_fiscQ       1000000 non-null  int64
#  6   m_decade      1000000 non-null  int64
#  7   m_avg_rating  1000000 non-null  float64
#  8   m_quality     1000000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6)
# memory usage: 68.7 MB

# %%
data = data.sort_values(by=['r_date'])
data
# Out:
#           mid  cust_id  rating     r_date  r_year  r_fiscQ  m_decade
# 0        3113   510180     3.0 1999-12-12    1999        4         4  \
# 203      2953   510180     5.0 1999-12-16    1999        4         3
# 731     11242   830363     3.0 1999-12-21    1999        4         3
# 974      8327  1435350     5.0 1999-12-27    1999        4         2
# 1821    10152  1435350     5.0 1999-12-27    1999        4         4
# ...       ...      ...     ...        ...     ...      ...       ...
# 466354   1370   787052     4.0 2005-12-31    2005        4         2
# 703031  15764  1808587     4.0 2005-12-31    2005        4         5
# 179214   8107  2376148     3.0 2005-12-31    2005        4         3
# 519452  11219    35036     4.0 2005-12-31    2005        4         3
# 399197   5582  2644649     5.0 2005-12-31    2005        4         3
#
#         m_avg_rating  m_quality
# 0           3.187192          2
# 203         3.662879          3
# 731         3.843621          4
# 974         4.263282          4
# 1821        3.870432          4
# ...              ...        ...
# 466354      3.831081          4
# 703031      2.976311          2
# 179214      3.824645          4
# 519452      3.544118          3
# 399197      4.502756          4
#
# [1000000 rows x 9 columns]

# %%
scaler = MinMaxScaler()
data[['r_scaled']] = scaler.fit_transform(data[['rating']])
data.head()
# Out:
#         mid  cust_id  rating     r_date  r_year  r_fiscQ  m_decade
# 0      3113   510180     3.0 1999-12-12    1999        4         4  \
# 203    2953   510180     5.0 1999-12-16    1999        4         3
# 731   11242   830363     3.0 1999-12-21    1999        4         3
# 974    8327  1435350     5.0 1999-12-27    1999        4         2
# 1821  10152  1435350     5.0 1999-12-27    1999        4         4
#
#       m_avg_rating  m_quality  r_scaled
# 0         3.187192          2       0.5
# 203       3.662879          3       1.0
# 731       3.843621          4       0.5
# 974       4.263282          4       1.0
# 1821      3.870432          4       1.0

# %%
data['r_scaled'].mean()
# Out:
# 0.65142225

# %%
data_pivot = data.pivot(index='cust_id', columns='mid', values='rating')
data_pivot.head()
# Out:
# /var/folders/xc/4fn08svj2dgdk_3wj3xkp_rr0000gn/T/ipykernel_8959/1264852765.py:1: PerformanceWarning: The following operation may generate 4704446862 cells in the resulting pandas object.
#   data_pivot = data.pivot(index='cust_id', columns='mid', values='rating')
# mid      1      2      3      5      6      8      9      10     11     12
# cust_id
# 6          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  \
# 7          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 42         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 79         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# mid      ...  17761  17762  17763  17764  17765  17766  17767  17768  17769
# cust_id  ...
# 6        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  \
# 7        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 42       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 79       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# mid      17770
# cust_id
# 6          NaN
# 7          NaN
# 8          NaN
# 42         NaN
# 79         NaN
#
# [5 rows x 16221 columns]

# %%
data_pivot = data_pivot.fillna(.65)
data_pivot.head()

# %%
data_pivot[79]

# %%
data_scaled

# %%
np.nan_to_num(data_scaled, nan=.5)

# %%
# %notify

# %% [markdown]
# # Train  Test Split
#
# temporal split

# %%
testsize = round(len(data) * 0.2)
testsize

# %%
#split based on time
df_train = data[:-(2*testsize)]
df_val = data[-(2*testsize):-testsize]
df_test = data[-testsize:]

# %%
df_train

# %%
df_val

# %%
df_test

# %% [markdown]
# # Train

# %%
f,ax = plt.subplots()

sns.scatterplot(x=X[:,0], y=X[:,1], ax=ax, hue=y, palette='colorblind')
ax.get_legend().remove()

# %%
train_table = df_train.pivot(index='cust_id', columns='mid', values='rating')
train_table.head()

# %%
train_table = scaler.transform(train_table)

# %%
np.nan_to_num(train_table, nan=.5)

# %%
# %notify

# %% [markdown]
# # Val

# %%
val_table = df_val.pivot(index='cust_id', columns='mid', values='rating')
val_table.head()

# %% [markdown]
# # Test

# %%
test_table = df_test.pivot(index='cust_id', columns='mid', values='rating')
test_table.head()

# %%
train_scaled = scaler.fit_transform(train_table)

# %%
train_scaled = train_scaled.fillna(.5)
train_scaled

# %%
# %notify

# %%
# %notify
