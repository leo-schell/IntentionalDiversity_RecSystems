# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.neighbors import NearestNeighbors

from scipy.sparse import csr_matrix

# %%
#notify me when a long running cell is complete
# %load_ext jupyternotify
import time

# %%
data = pd.read_csv('data/final_df.csv')
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#     mid  cust_id  rating      r_date  r_year  r_fiscQ  m_decade  m_avg_rating
# 0  3113   510180     3.0  1999-12-12    1999        4         4           3.0  \
# 1  3113   739622     4.0  2001-07-15    2001        3         4           3.0
# 2  3113   200684     1.0  2001-10-15    2001        4         4           3.0
# 3  3113  2559624     3.0  2002-08-27    2002        3         4           3.0
# 4  3113  1557262     3.0  2003-11-06    2003        4         4           3.0
#
#    m_quality
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   mid           100000 non-null  int64
#  1   cust_id       100000 non-null  int64
#  2   rating        100000 non-null  float64
#  3   r_date        100000 non-null  object
#  4   r_year        100000 non-null  int64
#  5   r_fiscQ       100000 non-null  int64
#  6   m_decade      100000 non-null  int64
#  7   m_avg_rating  100000 non-null  float64
#  8   m_quality     100000 non-null  int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 6.9+ MB

# %%
data['r_date'] = data['r_date'].astype('datetime64[ns]')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   mid           100000 non-null  int64
#  1   cust_id       100000 non-null  int64
#  2   rating        100000 non-null  float64
#  3   r_date        100000 non-null  datetime64[ns]
#  4   r_year        100000 non-null  int64
#  5   r_fiscQ       100000 non-null  int64
#  6   m_decade      100000 non-null  int64
#  7   m_avg_rating  100000 non-null  float64
#  8   m_quality     100000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6)
# memory usage: 6.9 MB

# %%
data = data.sort_values(by=['r_date'])
data
# Out:
#          mid  cust_id  rating     r_date  r_year  r_fiscQ  m_decade
# 0       3113   510180     3.0 1999-12-12    1999        4         4  \
# 19     11242   830363     3.0 1999-12-21    1999        4         3
# 133     1642   872963     4.0 1999-12-30    1999        4         4
# 178    14574   882798     3.0 1999-12-30    1999        4         4
# 59     16438   882798     4.0 1999-12-30    1999        4         4
# ...      ...      ...     ...        ...     ...      ...       ...
# 56222  11443  1472304     4.0 2005-12-31    2005        4         5
# 84549  12596  1472871     3.0 2005-12-31    2005        4         2
# 29199   5317  1835727     1.0 2005-12-31    2005        4         5
# 30200   8376  1466372     4.0 2005-12-31    2005        4         5
# 99999  14141   899183     3.0 2005-12-31    2005        4         4
#
#        m_avg_rating  m_quality
# 0          3.000000          2
# 19         3.843750          3
# 133        4.044444          4
# 178        3.545455          3
# 59         3.824324          3
# ...             ...        ...
# 56222      4.186441          4
# 84549      2.600000          1
# 29199      3.403361          2
# 30200      3.545455          3
# 99999      3.000000          2
#
# [100000 rows x 9 columns]

# %%
scaler = MinMaxScaler()
data[['r_scaled']] = scaler.fit_transform(data[['rating']])
data.head()
# Out:
#        mid  cust_id  rating     r_date  r_year  r_fiscQ  m_decade
# 0     3113   510180     3.0 1999-12-12    1999        4         4  \
# 19   11242   830363     3.0 1999-12-21    1999        4         3
# 133   1642   872963     4.0 1999-12-30    1999        4         4
# 178  14574   882798     3.0 1999-12-30    1999        4         4
# 59   16438   882798     4.0 1999-12-30    1999        4         4
#
#      m_avg_rating  m_quality  r_scaled
# 0        3.000000          2      0.50
# 19       3.843750          3      0.50
# 133      4.044444          4      0.75
# 178      3.545455          3      0.50
# 59       3.824324          3      0.75

# %%
data['r_scaled'].mean()
# Out:
# 0.6508525

# %%
data_pivot = data.pivot(index='cust_id', columns='mid', values='r_scaled')
data_pivot.head()
# Out:
# mid      1      5      6      8      15     16     17     18     19     21
# cust_id
# 6          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  \
# 7          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 134        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 195        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 199        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# mid      ...  17756  17758  17760  17761  17762  17763  17764  17767  17768
# cust_id  ...
# 6        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  \
# 7        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 134      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 195      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 199      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# mid      17769
# cust_id
# 6          NaN
# 7          NaN
# 134        NaN
# 195        NaN
# 199        NaN
#
# [5 rows x 9227 columns]

# %%
data_pivot = data_pivot.fillna(.65)
data_pivot.head()
# Out:
# mid      1      5      6      8      15     16     17     18     19     21
# cust_id
# 6         0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65  \
# 7         0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
# 134       0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
# 195       0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
# 199       0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
#
# mid      ...  17756  17758  17760  17761  17762  17763  17764  17767  17768
# cust_id  ...
# 6        ...   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65  \
# 7        ...   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
# 134      ...   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
# 195      ...   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
# 199      ...   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65   0.65
#
# mid      17769
# cust_id
# 6         0.65
# 7         0.65
# 134       0.65
# 195       0.65
# 199       0.65
#
# [5 rows x 9227 columns]

# %%
data_pivot[79].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 77372 entries, 6 to 2649378
# Series name: 79
# Non-Null Count  Dtype
# --------------  -----
# 77372 non-null  float64
# dtypes: float64(1)
# memory usage: 1.2 MB

# %%
data_csr = csr_matrix(data_pivot.values)

# %%
knn = NearestNeighbors(metric='euclidean', algorithm='brute')

# %%
knn.fit(data_csr)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean')

# %%
knn.n_features_in_
# Out:
# 9227

# %%
knn.kneighbors([[6,1]], n_neighbors=5, return_distance=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xc/4fn08svj2dgdk_3wj3xkp_rr0000gn/T/ipykernel_2236/1214480564.py in <module>
# ----> 1 knn.kneighbors([[6,1]], n_neighbors=5, return_distance=True)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     715                 X = _check_precomputed(X)
#     716             else:
# --> 717                 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     718         else:
#     719             query_is_train = True
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     583
#     584         if not no_val_X and check_params.get("ensure_2d", True):
# --> 585             self._check_n_features(X, reset=reset)
#     586
#     587         return out
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     398
#     399         if n_features != self.n_features_in_:
# --> 400             raise ValueError(
#     401                 f"X has {n_features} features, but {self.__class__.__name__} "
#     402                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 2 features, but NearestNeighbors is expecting 9227 features as input.

# %%
data_scaled

# %%
np.nan_to_num(data_scaled, nan=.5)

# %%
# %notify

# %% [markdown]
# # Train  Test Split
#
# temporal split

# %%
testsize = round(len(data) * 0.2)
testsize

# %%
#split based on time
df_train = data[:-(2*testsize)]
df_val = data[-(2*testsize):-testsize]
df_test = data[-testsize:]

# %%
df_train

# %%
df_val

# %%
df_test

# %% [markdown]
# # Train

# %%
f,ax = plt.subplots()

sns.scatterplot(x=X[:,0], y=X[:,1], ax=ax, hue=y, palette='colorblind')
ax.get_legend().remove()

# %%
train_table = df_train.pivot(index='cust_id', columns='mid', values='rating')
train_table.head()

# %%
train_table = scaler.transform(train_table)

# %%
np.nan_to_num(train_table, nan=.5)

# %%
# %notify

# %% [markdown]
# # Val

# %%
val_table = df_val.pivot(index='cust_id', columns='mid', values='rating')
val_table.head()

# %% [markdown]
# # Test

# %%
test_table = df_test.pivot(index='cust_id', columns='mid', values='rating')
test_table.head()

# %%
train_scaled = scaler.fit_transform(train_table)

# %%
train_scaled = train_scaled.fillna(.5)
train_scaled

# %%
# %notify

# %%
# %notify
