# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import os
from surprise import Dataset
from surprise import Reader
from surprise import BaselineOnly
from surprise import accuracy
from surprise import SVD
from surprise.model_selection import cross_validate

# %%
#notify me when a long running cell is complete
# %load_ext jupyternotify
import time

# %%
data = pd.read_csv('data/final_df.csv')
data = data.drop(['Unnamed: 0', 'r_year', 'r_fiscQ', 'm_decade', 'm_avg_rating', 'm_quality'], axis=1)
data['r_date'] = data['r_date'].astype('datetime64[ns]')
data.info()
# Out:
#     mid  cust_id  rating      r_date
# 0  3113   510180     3.0  1999-12-12
# 1  3113   739622     4.0  2001-07-15
# 2  3113   200684     1.0  2001-10-15
# 3  3113  2559624     3.0  2002-08-27
# 4  3113  1557262     3.0  2003-11-06

# %%
#only those columns relevant to surprise
data = data[['mid', 'cust_id', 'rating', 'r_date']]
data.head()
# Out:
#        mid  cust_id  rating     r_date
# 0     3113   510180     3.0 1999-12-12
# 19   11242   830363     3.0 1999-12-21
# 133   1642   872963     4.0 1999-12-30
# 178  14574   882798     3.0 1999-12-30
# 59   16438   882798     4.0 1999-12-30

# %% [markdown]
# # Train/Test Split: out of time approach

# %%
testsize = round(len(data) * 0.2)
testsize
# Out:
# 20000

# %%
data.groupby('cust_id')['rating'].count().sort_values(ascending=False)
# Out:
# cust_id
# 305344     23
# 2118461    20
# 2439493    16
# 387418     15
# 1639792    14
#            ..
# 990585      1
# 990639      1
# 990697      1
# 990773      1
# 2649378     1
# Name: rating, Length: 77372, dtype: int64

# %% [markdown]
# This would work better with more data and less users who don't only vote once

# %%
data = data.sort_values(by=['cust_id'])
data = data[['cust_id', 'mid', 'rating', 'r_date']]
data
# Out:
#        cust_id    mid  rating     r_date
# 61077        6  10730     5.0 2004-09-15
# 86435        7   4465     2.0 2005-05-23
# 69300      134   3638     5.0 2004-11-28
# 25159      134  16912     5.0 2005-04-19
# 6587       195  11209     4.0 2005-05-16
# ...        ...    ...     ...        ...
# 83453  2649202  16265     4.0 2005-08-03
# 35733  2649257  17441     4.0 2005-10-08
# 21953  2649296    798     4.0 2002-02-19
# 9243   2649336   2862     4.0 2004-11-22
# 89382  2649378   6134     4.0 2005-03-26
#
# [100000 rows x 4 columns]

# %%
#splitting data into 3 groups based on how many reviews they've given
for cust in data['cust_id'].unique():
    i = data.index[data['cust_id'] == cust]
    
    #if more than 2, the final review will be in the test, 2nd to last will be in the val
    if len(i)> 2:
        data.loc[i[-1], 'split'] = 3
        data.loc[i[-2], 'split'] = 2
        data.loc[i[:-2], 'split'] = 1
        
    #if 2, the final review will be in the test
    if len(i) == 2:
        data.loc[i[-1], 'split'] = 3
        data.loc[i[0], 'split'] = 1
        
    #everyone with one review gets a temporal split linearly
    else:
        data.loc[i[0], 'split'] = 1
        
test = data[(data['split'] == 3)]
val = data[(data['split'] == 2)]
train = data[(data['split'] == 1 )]

# %%
test.shape
# Out:
# (16706, 5)

# %%
val.shape
# Out:
# (4180, 5)

# %%
train.shape
# Out:
# (79114, 5)

# %%
#sort vals by date, prep to split linearly
train = train.sort_values(by=['r_date'])
train
# Out:
#        cust_id    mid  rating     r_date  split
# 0       510180   3113     3.0 1999-12-12    1.0
# 51     2114455  17563     3.0 1999-12-30    1.0
# 178     882798  14574     3.0 1999-12-30    1.0
# 133     872963   1642     4.0 1999-12-30    1.0
# 277      64765   6534     5.0 2000-01-05    1.0
# ...        ...    ...     ...        ...    ...
# 52514   563705  14277     2.0 2005-12-31    1.0
# 55383   200254   2660     3.0 2005-12-31    1.0
# 12910    28205  10371     4.0 2005-12-31    1.0
# 82256   862011  14111     4.0 2005-12-31    1.0
# 94691  1639479  17324     4.0 2005-12-31    1.0
#
# [79114 rows x 5 columns]

# %%
#adding only the end of training set to test
test2 = train[-(testsize -len(test)):]
test = pd.concat([test, test2])

#20k
test.shape
# Out:
# (3294, 5)

# %%
#remove test rows
train = train.loc[~train.index.isin(test.index)]
train.shape
# Out:
# (75820, 5)

# %%
#sanity check
test = test.sort_values(by=['r_date'])
test
# Out:
#        cust_id    mid  rating     r_date  split
# 19      830363  11242     3.0 1999-12-21    3.0
# 59      882798  16438     4.0 1999-12-30    3.0
# 281     764785   9728     4.0 2000-01-06    3.0
# 437    1356928   8784     3.0 2000-01-07    3.0
# 678    1438498   8840     4.0 2000-01-07    3.0
# ...        ...    ...     ...        ...    ...
# 30350   307530   3106     3.0 2005-12-31    1.0
# 82993  2644224   4621     5.0 2005-12-31    1.0
# 17900  2638089  12500     3.0 2005-12-31    1.0
# 59843   594259  10596     3.0 2005-12-31    1.0
# 94691  1639479  17324     4.0 2005-12-31    1.0
#
# [20000 rows x 5 columns]

# %%
#same with val
val1 = train.sample(n=(20000-len(val)), replace=False, random_state=1)
val = pd.concat([val, val1])

#20k
val.shape
# Out:
# (20000, 5)

# %%
train = train.loc[~train.index.isin(val1.index)]
train.shape
# Out:
# (60000, 5)

# %% [markdown]
# # Baseline using Surprise

# %%
reader = Reader(rating_scale=(1,5))

# %%
train_data = Dataset.load_from_df(train[['cust_id','mid','rating']], reader)
val_data = Dataset.load_from_df(val[['cust_id','mid','rating']], reader)
test_data = Dataset.load_from_df(test[['cust_id','mid','rating']], reader)

# %%
train_sr = train_data.build_full_trainset()

val_sr_before = val_data.build_full_trainset()
val_sr = val_sr_before.build_testset()

test_sr_before = test_data.build_full_trainset()
test_sr = test_sr_before.build_testset()

# %%
#using als. 20 epochs because that is the svd default
bsl_options = {'method': 'als', 'n_epochs':20}
bias_baseline = BaselineOnly(bsl_options)
bias_baseline.fit(train_sr)
predictions = bias_baseline.test(val_sr)
# Out:
# Estimating biases using als...

# %%
predictions
# Out:
# [Prediction(uid=1333, iid=13840, r_ui=4.0, est=3.456016872617161, details={'was_impossible': False}),
#  Prediction(uid=2128, iid=16869, r_ui=4.0, est=3.651227496290015, details={'was_impossible': False}),
#  Prediction(uid=2225, iid=16604, r_ui=4.0, est=3.867963, details={'was_impossible': False}),
#  Prediction(uid=2469, iid=7511, r_ui=3.0, est=3.701378303664416, details={'was_impossible': False}),
#  Prediction(uid=4306, iid=7294, r_ui=3.0, est=3.2124221571373894, details={'was_impossible': False}),
#  Prediction(uid=4421, iid=16425, r_ui=4.0, est=3.494912285714286, details={'was_impossible': False}),
#  Prediction(uid=5569, iid=5612, r_ui=4.0, est=3.31206347416836, details={'was_impossible': False}),
#  Prediction(uid=6206, iid=12161, r_ui=5.0, est=3.6808555148312587, details={'was_impossible': False}),
#  Prediction(uid=6785, iid=4080, r_ui=4.0, est=3.5565255891089107, details={'was_impossible': False}),
#  Prediction(uid=7070, iid=5181, r_ui=3.0, est=3.583818782324653, details={'was_impossible': False}),
#  Prediction(uid=8117, iid=406, r_ui=4.0, est=3.470342727835409, details={'was_impossible': False}),
#  Prediction(uid=8117, iid=10170, r_ui=4.0, est=3.323873684210526, details={'was_impossible': False}),
#  Prediction(uid=8212, iid=2360, r_ui=4.0, est=4.028864084506534, details={'was_impossible': False}),
#  Prediction(uid=9399, iid=1571, r_ui=5.0, est=3.5744769391304345, details={'was_impossible': False}),
#  Prediction(uid=10947, iid=12307, r_ui=3.0, est=3.5863650976267176, details={'was_impossible': False}),
#  Prediction(uid=11043, iid=15807, r_ui=5.0, est=3.7319768379383125, details={'was_impossible': False}),
#  Prediction(uid=11043, iid=9049, r_ui=4.0, est=3.496928558004963, details={'was_impossible': False}),
#  Prediction(uid=12138, iid=14702, r_ui=3.0, est=3.8316126397746215, details={'was_impossible': False}),
#  Prediction(uid=12253, iid=8393, r_ui=4.0, est=3.866675639097744, details={'was_impossible': False}),
#  Prediction(uid=12812, iid=8523, r_ui=3.0, est=3.742201038961039, details={'was_impossible': False}),
#  Prediction(uid=13269, iid=9160, r_ui=3.0, est=3.470250741182917, details={'was_impossible': False}),
#  Prediction(uid=13432, iid=4043, r_ui=4.0, est=3.7009492337889034, details={'was_impossible': False}),
#  Prediction(uid=14628, iid=2580, r_ui=3.0, est=3.466202572163356, details={'was_impossible': False}),
#  Prediction(uid=14682, iid=3736, r_ui=2.0, est=3.6585903257785772, details={'was_impossible': False}),
#  Prediction(uid=15538, iid=4977, r_ui=3.0, est=3.4650355415365843, details={'was_impossible': False}),
#  Prediction(uid=16475, iid=11242, r_ui=3.0, est=3.729249743981275, details={'was_impossible': False}),
#  Prediction(uid=16475, iid=16946, r_ui=5.0, est=3.60228286849934, details={'was_impossible': False}),
#  Prediction(uid=16565, iid=15803, r_ui=3.0, est=3.1593278109630565, details={'was_impossible': False}),
#  Prediction(uid=17189, iid=4849, r_ui=4.0, est=3.5018718509955944, details={'was_impossible': False}),
#  Prediction(uid=17189, iid=11004, r_ui=3.0, est=3.447490909090909, details={'was_impossible': False}),
#  Prediction(uid=17227, iid=16596, r_ui=4.0, est=3.719022178609331, details={'was_impossible': False}),
#  Prediction(uid=17451, iid=6235, r_ui=5.0, est=3.4719704940836875, details={'was_impossible': False}),
#  Prediction(uid=17451, iid=10889, r_ui=5.0, est=3.6194571428571427, details={'was_impossible': False}),
#  Prediction(uid=17864, iid=8651, r_ui=4.0, est=3.321140080804965, details={'was_impossible': False}),
#  Prediction(uid=18576, iid=11875, r_ui=3.0, est=3.6063584415584415, details={'was_impossible': False}),
#  Prediction(uid=18576, iid=9368, r_ui=4.0, est=3.511122580645161, details={'was_impossible': False}),
#  Prediction(uid=18851, iid=17405, r_ui=5.0, est=3.640491089108911, details={'was_impossible': False}),
#  Prediction(uid=18851, iid=13195, r_ui=5.0, est=3.575556436350999, details={'was_impossible': False}),
#  Prediction(uid=18907, iid=17308, r_ui=2.0, est=3.4394765254088266, details={'was_impossible': False}),
#  Prediction(uid=19930, iid=6016, r_ui=3.0, est=3.6764840354767183, details={'was_impossible': False}),
#  Prediction(uid=21823, iid=12758, r_ui=4.0, est=3.7558583378867416, details={'was_impossible': False}),
#  Prediction(uid=22718, iid=10620, r_ui=5.0, est=3.561934018548436, details={'was_impossible': False}),
#  Prediction(uid=26210, iid=11977, r_ui=3.0, est=3.5629330347144457, details={'was_impossible': False}),
#  Prediction(uid=26334, iid=13610, r_ui=3.0, est=3.1905265288904703, details={'was_impossible': False}),
#  Prediction(uid=26762, iid=718, r_ui=2.0, est=3.475204394956376, details={'was_impossible': False}),
#  Prediction(uid=27289, iid=6206, r_ui=5.0, est=3.8386929819636104, details={'was_impossible': False}),
#  Prediction(uid=27289, iid=3798, r_ui=3.0, est=3.9420851727123276, details={'was_impossible': False}),
#  Prediction(uid=27815, iid=12690, r_ui=5.0, est=4.083388261426299, details={'was_impossible': False}),
#  Prediction(uid=29236, iid=10734, r_ui=5.0, est=3.833078246183755, details={'was_impossible': False}),
#  Prediction(uid=30941, iid=11165, r_ui=3.0, est=3.708075336585366, details={'was_impossible': False}),
#  Prediction(uid=31585, iid=17452, r_ui=1.0, est=3.4603680563380284, details={'was_impossible': False}),
#  Prediction(uid=33089, iid=8243, r_ui=3.0, est=3.2429454545454544, details={'was_impossible': False}),
#  Prediction(uid=33089, iid=12317, r_ui=4.0, est=3.6912884210526316, details={'was_impossible': False}),
#  Prediction(uid=34795, iid=14047, r_ui=4.0, est=3.4988546739646704, details={'was_impossible': False}),
#  Prediction(uid=35017, iid=9265, r_ui=4.0, est=3.403367441860465, details={'was_impossible': False}),
#  Prediction(uid=35017, iid=14856, r_ui=5.0, est=3.6234593796773935, details={'was_impossible': False}),
#  Prediction(uid=35511, iid=5069, r_ui=3.0, est=3.625725842696629, details={'was_impossible': False}),
#  Prediction(uid=35511, iid=2992, r_ui=3.0, est=3.6611172413793103, details={'was_impossible': False}),
#  Prediction(uid=35824, iid=6231, r_ui=4.0, est=3.4876614505027863, details={'was_impossible': False}),
#  Prediction(uid=36822, iid=12160, r_ui=3.0, est=3.5239651449401497, details={'was_impossible': False}),
#  Prediction(uid=37249, iid=6736, r_ui=4.0, est=3.753058064516129, details={'was_impossible': False}),
#  Prediction(uid=37249, iid=15759, r_ui=2.0, est=3.480234146341463, details={'was_impossible': False}),
#  Prediction(uid=37797, iid=11846, r_ui=4.0, est=3.258263525142524, details={'was_impossible': False}),
#  Prediction(uid=37797, iid=10131, r_ui=3.0, est=3.3232128540058423, details={'was_impossible': False}),
#  Prediction(uid=38514, iid=12071, r_ui=5.0, est=3.806945178325149, details={'was_impossible': False}),
#  Prediction(uid=38514, iid=6971, r_ui=5.0, est=3.911598545454546, details={'was_impossible': False}),
#  Prediction(uid=38879, iid=16596, r_ui=2.0, est=3.701487171361411, details={'was_impossible': False}),
#  Prediction(uid=39242, iid=10165, r_ui=1.0, est=3.5836217686147065, details={'was_impossible': False}),
#  Prediction(uid=40233, iid=6372, r_ui=4.0, est=3.5153641236909214, details={'was_impossible': False}),
#  Prediction(uid=41422, iid=12881, r_ui=2.0, est=3.126386014329287, details={'was_impossible': False}),
#  Prediction(uid=41545, iid=1719, r_ui=3.0, est=3.1263395996466596, details={'was_impossible': False}),
#  Prediction(uid=41724, iid=3894, r_ui=3.0, est=3.100051235889718, details={'was_impossible': False}),
#  Prediction(uid=42147, iid=1255, r_ui=3.0, est=3.812520274172945, details={'was_impossible': False}),
#  Prediction(uid=43279, iid=11897, r_ui=3.0, est=3.687980433507906, details={'was_impossible': False}),
#  Prediction(uid=43530, iid=16844, r_ui=2.0, est=3.5252415789473686, details={'was_impossible': False}),
#  Prediction(uid=43751, iid=13015, r_ui=3.0, est=3.929096629213483, details={'was_impossible': False}),
#  Prediction(uid=43751, iid=270, r_ui=2.0, est=4.0661014152984905, details={'was_impossible': False}),
#  Prediction(uid=44490, iid=4996, r_ui=3.0, est=3.382460636750258, details={'was_impossible': False}),
#  Prediction(uid=44807, iid=1087, r_ui=2.0, est=3.635438947368421, details={'was_impossible': False}),
#  Prediction(uid=45234, iid=381, r_ui=2.0, est=3.6284075109644296, details={'was_impossible': False}),
#  Prediction(uid=45234, iid=6206, r_ui=3.0, est=3.8700057560859347, details={'was_impossible': False}),
#  Prediction(uid=45392, iid=10981, r_ui=3.0, est=3.7770686613594173, details={'was_impossible': False}),
#  Prediction(uid=45392, iid=10899, r_ui=3.0, est=3.6302126267163, details={'was_impossible': False}),
#  Prediction(uid=46086, iid=11276, r_ui=4.0, est=3.4394818736141906, details={'was_impossible': False}),
#  Prediction(uid=47075, iid=8149, r_ui=2.0, est=3.5364646905269854, details={'was_impossible': False}),
#  Prediction(uid=47075, iid=12675, r_ui=5.0, est=3.7755652512676834, details={'was_impossible': False}),
#  Prediction(uid=49890, iid=963, r_ui=4.0, est=3.8508812086726323, details={'was_impossible': False}),
#  Prediction(uid=50669, iid=16499, r_ui=1.0, est=3.558736172070299, details={'was_impossible': False}),
#  Prediction(uid=51746, iid=14815, r_ui=3.0, est=3.7023006097560973, details={'was_impossible': False}),
#  Prediction(uid=52191, iid=11165, r_ui=4.0, est=3.6983568, details={'was_impossible': False}),
#  Prediction(uid=53694, iid=14185, r_ui=4.0, est=3.966021690560417, details={'was_impossible': False}),
#  Prediction(uid=54577, iid=12471, r_ui=3.0, est=3.3777882352941178, details={'was_impossible': False}),
#  Prediction(uid=55339, iid=9431, r_ui=5.0, est=3.653264064226333, details={'was_impossible': False}),
#  Prediction(uid=55339, iid=197, r_ui=4.0, est=3.359558635405605, details={'was_impossible': False}),
#  Prediction(uid=56854, iid=12084, r_ui=4.0, est=3.3503796610169494, details={'was_impossible': False}),
#  Prediction(uid=56854, iid=9074, r_ui=2.0, est=3.674246808510638, details={'was_impossible': False}),
#  Prediction(uid=57186, iid=8954, r_ui=3.0, est=3.4306569613214464, details={'was_impossible': False}),
#  Prediction(uid=57633, iid=1027, r_ui=2.0, est=3.188359806694075, details={'was_impossible': False}),
#  Prediction(uid=57633, iid=1482, r_ui=2.0, est=3.365321798810454, details={'was_impossible': False}),
#  Prediction(uid=58489, iid=11531, r_ui=2.0, est=3.481622264228765, details={'was_impossible': False}),
#  Prediction(uid=58959, iid=4697, r_ui=5.0, est=3.8242196082650324, details={'was_impossible': False}),
#  Prediction(uid=59052, iid=8722, r_ui=2.0, est=3.6109558646616544, details={'was_impossible': False}),
#  Prediction(uid=59876, iid=4080, r_ui=5.0, est=3.5659403848835587, details={'was_impossible': False}),
#  Prediction(uid=61472, iid=6356, r_ui=3.0, est=3.523692664311983, details={'was_impossible': False}),
#  Prediction(uid=61472, iid=15440, r_ui=3.0, est=3.5958380388438003, details={'was_impossible': False}),
#  Prediction(uid=61472, iid=7057, r_ui=4.0, est=4.319509905691293, details={'was_impossible': False}),
#  Prediction(uid=61810, iid=6902, r_ui=4.0, est=3.78128468218745, details={'was_impossible': False}),
#  Prediction(uid=62691, iid=17324, r_ui=4.0, est=3.972916738197425, details={'was_impossible': False}),
#  Prediction(uid=62691, iid=3254, r_ui=3.0, est=3.1147836225062213, details={'was_impossible': False}),
#  Prediction(uid=63786, iid=6119, r_ui=2.0, est=3.2914680643887926, details={'was_impossible': False}),
#  Prediction(uid=63971, iid=7904, r_ui=4.0, est=3.200192589385129, details={'was_impossible': False}),
#  Prediction(uid=63971, iid=3859, r_ui=2.0, est=3.671772881355932, details={'was_impossible': False}),
#  Prediction(uid=64741, iid=12818, r_ui=4.0, est=3.5622029385265384, details={'was_impossible': False}),
#  Prediction(uid=64741, iid=1867, r_ui=4.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=65972, iid=10678, r_ui=3.0, est=3.452182889551205, details={'was_impossible': False}),
#  Prediction(uid=66120, iid=4144, r_ui=5.0, est=3.512355163104612, details={'was_impossible': False}),
#  Prediction(uid=66179, iid=12785, r_ui=5.0, est=3.7702588381755375, details={'was_impossible': False}),
#  Prediction(uid=69801, iid=6134, r_ui=4.0, est=3.628413569962124, details={'was_impossible': False}),
#  Prediction(uid=70328, iid=12778, r_ui=3.0, est=3.619073499960476, details={'was_impossible': False}),
#  Prediction(uid=70476, iid=6195, r_ui=4.0, est=3.1116116548084856, details={'was_impossible': False}),
#  Prediction(uid=70565, iid=1703, r_ui=3.0, est=3.758992674721627, details={'was_impossible': False}),
#  Prediction(uid=70565, iid=14459, r_ui=5.0, est=3.6176877297166743, details={'was_impossible': False}),
#  Prediction(uid=71594, iid=12252, r_ui=2.0, est=3.6631176791375077, details={'was_impossible': False}),
#  Prediction(uid=71743, iid=1642, r_ui=5.0, est=4.088517709002753, details={'was_impossible': False}),
#  Prediction(uid=71743, iid=14188, r_ui=4.0, est=3.47847640160999, details={'was_impossible': False}),
#  Prediction(uid=72607, iid=7716, r_ui=3.0, est=3.795608711433265, details={'was_impossible': False}),
#  Prediction(uid=72607, iid=9074, r_ui=4.0, est=3.716063519943903, details={'was_impossible': False}),
#  Prediction(uid=73023, iid=13847, r_ui=5.0, est=3.7125221052631576, details={'was_impossible': False}),
#  Prediction(uid=73023, iid=16147, r_ui=5.0, est=4.237056819809715, details={'was_impossible': False}),
#  Prediction(uid=73997, iid=3276, r_ui=5.0, est=3.442019448014205, details={'was_impossible': False}),
#  Prediction(uid=74533, iid=3935, r_ui=4.0, est=3.8105850067794425, details={'was_impossible': False}),
#  Prediction(uid=74533, iid=6482, r_ui=2.0, est=3.579133263659069, details={'was_impossible': False}),
#  Prediction(uid=76023, iid=11781, r_ui=2.0, est=4.182018946575104, details={'was_impossible': False}),
#  Prediction(uid=76023, iid=1976, r_ui=3.0, est=3.5778346474694573, details={'was_impossible': False}),
#  Prediction(uid=76604, iid=8651, r_ui=2.0, est=3.378609316872312, details={'was_impossible': False}),
#  Prediction(uid=77084, iid=16349, r_ui=4.0, est=3.841428010670732, details={'was_impossible': False}),
#  Prediction(uid=77504, iid=12125, r_ui=5.0, est=3.835769703504043, details={'was_impossible': False}),
#  Prediction(uid=77989, iid=1854, r_ui=3.0, est=3.5139636011234545, details={'was_impossible': False}),
#  Prediction(uid=78475, iid=463, r_ui=3.0, est=3.648274285714286, details={'was_impossible': False}),
#  Prediction(uid=78475, iid=15563, r_ui=3.0, est=3.5029220338983054, details={'was_impossible': False}),
#  Prediction(uid=78504, iid=2171, r_ui=3.0, est=3.6352530467573883, details={'was_impossible': False}),
#  Prediction(uid=78846, iid=4705, r_ui=3.0, est=3.5355917602785425, details={'was_impossible': False}),
#  Prediction(uid=79408, iid=17560, r_ui=4.0, est=3.715078188070509, details={'was_impossible': False}),
#  Prediction(uid=79811, iid=12171, r_ui=3.0, est=2.8709106158246254, details={'was_impossible': False}),
#  Prediction(uid=83992, iid=11391, r_ui=4.0, est=3.530284210526316, details={'was_impossible': False}),
#  Prediction(uid=83992, iid=4698, r_ui=4.0, est=3.347554507556019, details={'was_impossible': False}),
#  Prediction(uid=89248, iid=16465, r_ui=4.0, est=3.377209971255599, details={'was_impossible': False}),
#  Prediction(uid=89256, iid=10460, r_ui=5.0, est=3.733988571428571, details={'was_impossible': False}),
#  Prediction(uid=89256, iid=16605, r_ui=4.0, est=3.721322448979592, details={'was_impossible': False}),
#  Prediction(uid=89510, iid=15078, r_ui=3.0, est=3.21591648586188, details={'was_impossible': False}),
#  Prediction(uid=90051, iid=11040, r_ui=4.0, est=3.9005824937352336, details={'was_impossible': False}),
#  Prediction(uid=91979, iid=758, r_ui=1.0, est=3.4477126530612243, details={'was_impossible': False}),
#  Prediction(uid=91979, iid=16550, r_ui=4.0, est=3.6997463414634146, details={'was_impossible': False}),
#  Prediction(uid=91990, iid=6196, r_ui=5.0, est=4.106582303912267, details={'was_impossible': False}),
#  Prediction(uid=91990, iid=14047, r_ui=4.0, est=3.5396152671755723, details={'was_impossible': False}),
#  Prediction(uid=92343, iid=14973, r_ui=4.0, est=3.427219841188238, details={'was_impossible': False}),
#  Prediction(uid=92774, iid=3624, r_ui=3.0, est=3.968613351604421, details={'was_impossible': False}),
#  Prediction(uid=93355, iid=4418, r_ui=3.0, est=3.708420090946672, details={'was_impossible': False}),
#  Prediction(uid=94821, iid=5997, r_ui=5.0, est=3.6597699373718817, details={'was_impossible': False}),
#  Prediction(uid=94821, iid=11279, r_ui=3.0, est=3.617569755077446, details={'was_impossible': False}),
#  Prediction(uid=96397, iid=4356, r_ui=4.0, est=3.708883271375465, details={'was_impossible': False}),
#  Prediction(uid=96397, iid=11781, r_ui=5.0, est=4.152626615286761, details={'was_impossible': False}),
#  Prediction(uid=97439, iid=2800, r_ui=5.0, est=3.5702487524542614, details={'was_impossible': False}),
#  Prediction(uid=97578, iid=6150, r_ui=2.0, est=3.4862430975773187, details={'was_impossible': False}),
#  Prediction(uid=98347, iid=3962, r_ui=5.0, est=4.426010509125059, details={'was_impossible': False}),
#  Prediction(uid=98676, iid=6357, r_ui=4.0, est=3.4022883116883116, details={'was_impossible': False}),
#  Prediction(uid=99400, iid=9055, r_ui=5.0, est=3.6416857142857144, details={'was_impossible': False}),
#  Prediction(uid=99454, iid=12365, r_ui=3.0, est=3.4367249449204404, details={'was_impossible': False}),
#  Prediction(uid=100712, iid=7590, r_ui=4.0, est=3.5679691654070416, details={'was_impossible': False}),
#  Prediction(uid=100864, iid=9863, r_ui=4.0, est=2.930325389769151, details={'was_impossible': False}),
#  Prediction(uid=100864, iid=2940, r_ui=3.0, est=3.5181420457164276, details={'was_impossible': False}),
#  Prediction(uid=101554, iid=13855, r_ui=5.0, est=3.733988571428571, details={'was_impossible': False}),
#  Prediction(uid=101554, iid=12843, r_ui=2.0, est=3.494132566705597, details={'was_impossible': False}),
#  Prediction(uid=101807, iid=16209, r_ui=4.0, est=3.6520363636363635, details={'was_impossible': False}),
#  Prediction(uid=101807, iid=16312, r_ui=5.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=102487, iid=12237, r_ui=4.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=102487, iid=4862, r_ui=3.0, est=3.833137893063133, details={'was_impossible': False}),
#  Prediction(uid=103399, iid=11446, r_ui=3.0, est=3.810577254105095, details={'was_impossible': False}),
#  Prediction(uid=104544, iid=2186, r_ui=4.0, est=3.701408609504859, details={'was_impossible': False}),
#  Prediction(uid=104721, iid=13412, r_ui=2.0, est=3.902838519392408, details={'was_impossible': False}),
#  Prediction(uid=105221, iid=2371, r_ui=5.0, est=3.5879593220338983, details={'was_impossible': False}),
#  Prediction(uid=105221, iid=12675, r_ui=4.0, est=3.7755652512676834, details={'was_impossible': False}),
#  Prediction(uid=105532, iid=8846, r_ui=3.0, est=3.579375209977125, details={'was_impossible': False}),
#  Prediction(uid=105532, iid=5528, r_ui=3.0, est=3.4380697059329353, details={'was_impossible': False}),
#  Prediction(uid=105595, iid=16524, r_ui=2.0, est=3.7184170044460476, details={'was_impossible': False}),
#  Prediction(uid=106062, iid=10451, r_ui=5.0, est=3.6692425852068165, details={'was_impossible': False}),
#  Prediction(uid=106062, iid=2333, r_ui=3.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=107127, iid=16565, r_ui=2.0, est=3.691244501427641, details={'was_impossible': False}),
#  Prediction(uid=107787, iid=5775, r_ui=2.0, est=3.78273313789232, details={'was_impossible': False}),
#  Prediction(uid=107787, iid=15748, r_ui=5.0, est=3.4827574468085105, details={'was_impossible': False}),
#  Prediction(uid=107840, iid=1324, r_ui=4.0, est=4.054841795352862, details={'was_impossible': False}),
#  Prediction(uid=107840, iid=15, r_ui=3.0, est=3.6485475251509056, details={'was_impossible': False}),
#  Prediction(uid=108397, iid=6196, r_ui=3.0, est=4.140410875340838, details={'was_impossible': False}),
#  Prediction(uid=108936, iid=13582, r_ui=3.0, est=3.640677144607668, details={'was_impossible': False}),
#  Prediction(uid=108936, iid=10131, r_ui=5.0, est=3.398741328863318, details={'was_impossible': False}),
#  Prediction(uid=110288, iid=4906, r_ui=3.0, est=3.6758743192291576, details={'was_impossible': False}),
#  Prediction(uid=110288, iid=17290, r_ui=4.0, est=3.645854838709677, details={'was_impossible': False}),
#  Prediction(uid=110288, iid=14828, r_ui=5.0, est=3.645854838709677, details={'was_impossible': False}),
#  Prediction(uid=111086, iid=16721, r_ui=2.0, est=3.679286862994745, details={'was_impossible': False}),
#  Prediction(uid=111736, iid=6615, r_ui=3.0, est=4.0246791094956835, details={'was_impossible': False}),
#  Prediction(uid=111772, iid=7607, r_ui=3.0, est=3.671481081081081, details={'was_impossible': False}),
#  Prediction(uid=111772, iid=10947, r_ui=5.0, est=4.253236859120773, details={'was_impossible': False}),
#  Prediction(uid=111824, iid=3321, r_ui=3.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=111824, iid=7595, r_ui=4.0, est=3.455593640772013, details={'was_impossible': False}),
#  Prediction(uid=112320, iid=1615, r_ui=4.0, est=3.6659037677276594, details={'was_impossible': False}),
#  Prediction(uid=112684, iid=9828, r_ui=4.0, est=3.805889832535885, details={'was_impossible': False}),
#  Prediction(uid=112913, iid=12785, r_ui=4.0, est=3.8549043266430623, details={'was_impossible': False}),
#  Prediction(uid=113029, iid=9593, r_ui=5.0, est=3.8237438206685486, details={'was_impossible': False}),
#  Prediction(uid=113068, iid=14852, r_ui=5.0, est=3.6150634331817444, details={'was_impossible': False}),
#  Prediction(uid=113090, iid=16272, r_ui=2.0, est=4.057487464085757, details={'was_impossible': False}),
#  Prediction(uid=113092, iid=4356, r_ui=2.0, est=3.7317316947732917, details={'was_impossible': False}),
#  Prediction(uid=113262, iid=12092, r_ui=2.0, est=3.2116921117981567, details={'was_impossible': False}),
#  Prediction(uid=113416, iid=17303, r_ui=2.0, est=3.2274382978723404, details={'was_impossible': False}),
#  Prediction(uid=113416, iid=6988, r_ui=3.0, est=3.6140610978543997, details={'was_impossible': False}),
#  Prediction(uid=113499, iid=13471, r_ui=4.0, est=3.6008954126388564, details={'was_impossible': False}),
#  Prediction(uid=113799, iid=16406, r_ui=1.0, est=3.5765383177570094, details={'was_impossible': False}),
#  Prediction(uid=113799, iid=7937, r_ui=3.0, est=3.73714435063724, details={'was_impossible': False}),
#  Prediction(uid=114187, iid=11064, r_ui=4.0, est=3.891986879677081, details={'was_impossible': False}),
#  Prediction(uid=114187, iid=1799, r_ui=4.0, est=3.69912472986286, details={'was_impossible': False}),
#  Prediction(uid=115267, iid=2813, r_ui=3.0, est=3.758800017973768, details={'was_impossible': False}),
#  Prediction(uid=115392, iid=9886, r_ui=3.0, est=3.7887074542056074, details={'was_impossible': False}),
#  Prediction(uid=116140, iid=6623, r_ui=3.0, est=3.4856237597759963, details={'was_impossible': False}),
#  Prediction(uid=116252, iid=6913, r_ui=4.0, est=3.56256, details={'was_impossible': False}),
#  Prediction(uid=116252, iid=16596, r_ui=3.0, est=3.6866117647058823, details={'was_impossible': False}),
#  Prediction(uid=116353, iid=11384, r_ui=3.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=116353, iid=9905, r_ui=3.0, est=3.56256, details={'was_impossible': False}),
#  Prediction(uid=116563, iid=11886, r_ui=2.0, est=3.4660235294117645, details={'was_impossible': False}),
#  Prediction(uid=116563, iid=5287, r_ui=4.0, est=3.6939492441469652, details={'was_impossible': False}),
#  Prediction(uid=116858, iid=4262, r_ui=4.0, est=3.9306336893187774, details={'was_impossible': False}),
#  Prediction(uid=117112, iid=10126, r_ui=4.0, est=3.706869342087708, details={'was_impossible': False}),
#  Prediction(uid=117507, iid=3917, r_ui=4.0, est=3.739541116751269, details={'was_impossible': False}),
#  Prediction(uid=117507, iid=14940, r_ui=3.0, est=3.514126451612903, details={'was_impossible': False}),
#  Prediction(uid=117949, iid=9351, r_ui=4.0, est=3.2533493422784794, details={'was_impossible': False}),
#  Prediction(uid=118260, iid=7294, r_ui=3.0, est=3.3093821363535083, details={'was_impossible': False}),
#  Prediction(uid=118579, iid=17157, r_ui=5.0, est=4.1895460262402455, details={'was_impossible': False}),
#  Prediction(uid=118706, iid=5939, r_ui=1.0, est=3.3595236721199333, details={'was_impossible': False}),
#  Prediction(uid=118706, iid=7833, r_ui=5.0, est=3.8634882697286006, details={'was_impossible': False}),
#  Prediction(uid=119279, iid=2900, r_ui=4.0, est=3.648274285714286, details={'was_impossible': False}),
#  Prediction(uid=119497, iid=7827, r_ui=5.0, est=3.4695443334284897, details={'was_impossible': False}),
#  Prediction(uid=119790, iid=6042, r_ui=3.0, est=3.149287929877425, details={'was_impossible': False}),
#  Prediction(uid=121182, iid=12409, r_ui=3.0, est=3.66298025974026, details={'was_impossible': False}),
#  Prediction(uid=122057, iid=10820, r_ui=3.0, est=4.090364305619852, details={'was_impossible': False}),
#  Prediction(uid=122057, iid=9508, r_ui=4.0, est=3.3335999999999997, details={'was_impossible': False}),
#  Prediction(uid=122197, iid=13378, r_ui=5.0, est=3.4992465473152063, details={'was_impossible': False}),
#  Prediction(uid=123846, iid=3794, r_ui=4.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=123846, iid=11283, r_ui=5.0, est=4.182881632653061, details={'was_impossible': False}),
#  Prediction(uid=124014, iid=9459, r_ui=4.0, est=3.429046271777003, details={'was_impossible': False}),
#  Prediction(uid=124237, iid=6971, r_ui=5.0, est=3.9610291658301864, details={'was_impossible': False}),
#  Prediction(uid=124440, iid=6844, r_ui=4.0, est=3.1609239718008055, details={'was_impossible': False}),
#  Prediction(uid=124810, iid=7683, r_ui=5.0, est=3.868867605633803, details={'was_impossible': False}),
#  Prediction(uid=124810, iid=7294, r_ui=2.0, est=3.2673220398082234, details={'was_impossible': False}),
#  Prediction(uid=124829, iid=15329, r_ui=2.0, est=3.360118581721834, details={'was_impossible': False}),
#  Prediction(uid=125275, iid=14928, r_ui=2.0, est=3.8888698843909997, details={'was_impossible': False}),
#  Prediction(uid=125296, iid=4306, r_ui=4.0, est=4.186153391086086, details={'was_impossible': False}),
#  Prediction(uid=125296, iid=13015, r_ui=4.0, est=3.8899887640449435, details={'was_impossible': False}),
#  Prediction(uid=125493, iid=4870, r_ui=2.0, est=3.2368372307444098, details={'was_impossible': False}),
#  Prediction(uid=125765, iid=12513, r_ui=3.0, est=3.7931028571428573, details={'was_impossible': False}),
#  Prediction(uid=126485, iid=14725, r_ui=2.0, est=3.418274128384367, details={'was_impossible': False}),
#  Prediction(uid=127061, iid=13107, r_ui=4.0, est=3.847960985669278, details={'was_impossible': False}),
#  Prediction(uid=128234, iid=17157, r_ui=4.0, est=4.124727640271023, details={'was_impossible': False}),
#  Prediction(uid=128348, iid=5056, r_ui=3.0, est=3.362255833882663, details={'was_impossible': False}),
#  Prediction(uid=128348, iid=6918, r_ui=2.0, est=3.589858536585366, details={'was_impossible': False}),
#  Prediction(uid=128389, iid=2371, r_ui=4.0, est=3.746701775714688, details={'was_impossible': False}),
#  Prediction(uid=129766, iid=11779, r_ui=3.0, est=3.563917272053373, details={'was_impossible': False}),
#  Prediction(uid=129941, iid=15844, r_ui=5.0, est=4.115593677483825, details={'was_impossible': False}),
#  Prediction(uid=130650, iid=6336, r_ui=4.0, est=3.2946701298701297, details={'was_impossible': False}),
#  Prediction(uid=130650, iid=8078, r_ui=3.0, est=3.5200046052833747, details={'was_impossible': False}),
#  Prediction(uid=132594, iid=13234, r_ui=3.0, est=3.584112774122324, details={'was_impossible': False}),
#  Prediction(uid=133383, iid=4506, r_ui=5.0, est=3.8365677959905873, details={'was_impossible': False}),
#  Prediction(uid=133707, iid=10230, r_ui=3.0, est=3.5480992167359995, details={'was_impossible': False}),
#  Prediction(uid=133984, iid=16094, r_ui=2.0, est=3.670444394030109, details={'was_impossible': False}),
#  Prediction(uid=135215, iid=16436, r_ui=4.0, est=3.5241846508481562, details={'was_impossible': False}),
#  Prediction(uid=136058, iid=9950, r_ui=5.0, est=3.4983511430148244, details={'was_impossible': False}),
#  Prediction(uid=136058, iid=16534, r_ui=4.0, est=3.4940880852991296, details={'was_impossible': False}),
#  Prediction(uid=136455, iid=6971, r_ui=5.0, est=3.9231237180055825, details={'was_impossible': False}),
#  Prediction(uid=136630, iid=5223, r_ui=4.0, est=3.496315947467167, details={'was_impossible': False}),
#  Prediction(uid=136854, iid=759, r_ui=4.0, est=3.292810670320063, details={'was_impossible': False}),
#  Prediction(uid=136867, iid=15545, r_ui=4.0, est=3.640102434570907, details={'was_impossible': False}),
#  Prediction(uid=137546, iid=7308, r_ui=4.0, est=3.703345702479735, details={'was_impossible': False}),
#  Prediction(uid=137943, iid=2945, r_ui=1.0, est=3.282519132346371, details={'was_impossible': False}),
#  Prediction(uid=139078, iid=2938, r_ui=5.0, est=3.977012592137592, details={'was_impossible': False}),
#  Prediction(uid=139107, iid=12446, r_ui=4.0, est=3.6328496379726465, details={'was_impossible': False}),
#  Prediction(uid=139107, iid=152, r_ui=3.0, est=3.655060082846921, details={'was_impossible': False}),
#  Prediction(uid=139212, iid=15037, r_ui=4.0, est=3.591233803318775, details={'was_impossible': False}),
#  Prediction(uid=139212, iid=11384, r_ui=4.0, est=3.4404404368033683, details={'was_impossible': False}),
#  Prediction(uid=139852, iid=12246, r_ui=3.0, est=3.8563593035468338, details={'was_impossible': False}),
#  Prediction(uid=139942, iid=12015, r_ui=5.0, est=3.3861767404299945, details={'was_impossible': False}),
#  Prediction(uid=139964, iid=17100, r_ui=2.0, est=3.469446577643282, details={'was_impossible': False}),
#  Prediction(uid=141034, iid=6470, r_ui=3.0, est=3.445181079974932, details={'was_impossible': False}),
#  Prediction(uid=141876, iid=14113, r_ui=3.0, est=3.553727494606561, details={'was_impossible': False}),
#  Prediction(uid=142492, iid=12940, r_ui=5.0, est=3.726579515202616, details={'was_impossible': False}),
#  Prediction(uid=144099, iid=17762, r_ui=4.0, est=3.507616288766299, details={'was_impossible': False}),
#  Prediction(uid=144464, iid=8406, r_ui=3.0, est=3.476845714285714, details={'was_impossible': False}),
#  Prediction(uid=144464, iid=12690, r_ui=2.0, est=4.061193507327938, details={'was_impossible': False}),
#  Prediction(uid=144836, iid=2475, r_ui=4.0, est=3.8394619330143542, details={'was_impossible': False}),
#  Prediction(uid=144934, iid=16604, r_ui=5.0, est=3.863072727272727, details={'was_impossible': False}),
#  Prediction(uid=145873, iid=9970, r_ui=5.0, est=3.743968326159711, details={'was_impossible': False}),
#  Prediction(uid=146587, iid=2350, r_ui=3.0, est=3.5779815789473686, details={'was_impossible': False}),
#  Prediction(uid=146780, iid=5004, r_ui=5.0, est=3.777699369747899, details={'was_impossible': False}),
#  Prediction(uid=147078, iid=6283, r_ui=5.0, est=3.5868445689845867, details={'was_impossible': False}),
#  Prediction(uid=147386, iid=13313, r_ui=4.0, est=3.5031166755033767, details={'was_impossible': False}),
#  Prediction(uid=147386, iid=11846, r_ui=3.0, est=3.210333065747279, details={'was_impossible': False}),
#  Prediction(uid=147386, iid=17467, r_ui=3.0, est=3.3592985125557897, details={'was_impossible': False}),
#  Prediction(uid=147386, iid=17248, r_ui=2.0, est=3.524815351461565, details={'was_impossible': False}),
#  Prediction(uid=147386, iid=8476, r_ui=3.0, est=3.491841065747279, details={'was_impossible': False}),
#  Prediction(uid=147807, iid=15471, r_ui=3.0, est=3.3145613511577943, details={'was_impossible': False}),
#  Prediction(uid=149144, iid=15350, r_ui=5.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=149144, iid=16724, r_ui=5.0, est=3.674246808510638, details={'was_impossible': False}),
#  Prediction(uid=149489, iid=9685, r_ui=4.0, est=3.382936996527613, details={'was_impossible': False}),
#  Prediction(uid=150344, iid=4656, r_ui=4.0, est=3.872763627132162, details={'was_impossible': False}),
#  Prediction(uid=150525, iid=15282, r_ui=4.0, est=3.4430144934333957, details={'was_impossible': False}),
#  Prediction(uid=151004, iid=5903, r_ui=5.0, est=3.568370046588106, details={'was_impossible': False}),
#  Prediction(uid=151300, iid=4345, r_ui=4.0, est=3.815076282230275, details={'was_impossible': False}),
#  Prediction(uid=151300, iid=12238, r_ui=3.0, est=2.869471260756611, details={'was_impossible': False}),
#  Prediction(uid=151821, iid=3886, r_ui=3.0, est=3.657778773895847, details={'was_impossible': False}),
#  Prediction(uid=151821, iid=2302, r_ui=4.0, est=3.713021906116643, details={'was_impossible': False}),
#  Prediction(uid=151871, iid=256, r_ui=4.0, est=3.712555696345685, details={'was_impossible': False}),
#  Prediction(uid=152858, iid=16724, r_ui=3.0, est=3.6369283874580067, details={'was_impossible': False}),
#  Prediction(uid=152858, iid=4472, r_ui=4.0, est=3.6104678048897614, details={'was_impossible': False}),
#  Prediction(uid=152903, iid=7886, r_ui=3.0, est=3.480234146341463, details={'was_impossible': False}),
#  Prediction(uid=152903, iid=9946, r_ui=4.0, est=3.720218181818182, details={'was_impossible': False}),
#  Prediction(uid=153145, iid=6029, r_ui=4.0, est=3.90339487486895, details={'was_impossible': False}),
#  Prediction(uid=153576, iid=5363, r_ui=3.0, est=3.437113926610028, details={'was_impossible': False}),
#  Prediction(uid=154481, iid=16302, r_ui=4.0, est=4.068330575776997, details={'was_impossible': False}),
#  Prediction(uid=154591, iid=8105, r_ui=4.0, est=3.538632, details={'was_impossible': False}),
#  Prediction(uid=155342, iid=1700, r_ui=1.0, est=3.486742455657054, details={'was_impossible': False}),
#  Prediction(uid=156450, iid=8897, r_ui=2.0, est=3.5369520935175816, details={'was_impossible': False}),
#  Prediction(uid=156450, iid=17319, r_ui=4.0, est=3.6552720935175818, details={'was_impossible': False}),
#  Prediction(uid=157094, iid=5130, r_ui=2.0, est=3.509141509433962, details={'was_impossible': False}),
#  Prediction(uid=157814, iid=14940, r_ui=3.0, est=3.5479550230414745, details={'was_impossible': False}),
#  Prediction(uid=158498, iid=3579, r_ui=4.0, est=3.2996192363272736, details={'was_impossible': False}),
#  Prediction(uid=158785, iid=1011, r_ui=3.0, est=3.341930143113462, details={'was_impossible': False}),
#  Prediction(uid=159159, iid=14472, r_ui=3.0, est=3.4518162667969703, details={'was_impossible': False}),
#  Prediction(uid=159159, iid=10281, r_ui=3.0, est=3.3288098082623114, details={'was_impossible': False}),
#  Prediction(uid=159266, iid=13840, r_ui=4.0, est=3.528436363636364, details={'was_impossible': False}),
#  Prediction(uid=159266, iid=8387, r_ui=4.0, est=3.6774216578434924, details={'was_impossible': False}),
#  Prediction(uid=160194, iid=17764, r_ui=4.0, est=3.6239545799467074, details={'was_impossible': False}),
#  Prediction(uid=161950, iid=5401, r_ui=3.0, est=3.327782724108281, details={'was_impossible': False}),
#  Prediction(uid=163875, iid=5496, r_ui=3.0, est=3.6261516785710386, details={'was_impossible': False}),
#  Prediction(uid=163951, iid=4067, r_ui=3.0, est=3.885478752620922, details={'was_impossible': False}),
#  Prediction(uid=164114, iid=6266, r_ui=3.0, est=3.788462489941225, details={'was_impossible': False}),
#  Prediction(uid=165034, iid=10230, r_ui=5.0, est=3.5897135321821034, details={'was_impossible': False}),
#  Prediction(uid=165060, iid=10088, r_ui=4.0, est=4.080506163191966, details={'was_impossible': False}),
#  Prediction(uid=165247, iid=5253, r_ui=5.0, est=3.742882760290557, details={'was_impossible': False}),
#  Prediction(uid=165374, iid=5963, r_ui=4.0, est=3.664530837472368, details={'was_impossible': False}),
#  Prediction(uid=165720, iid=13052, r_ui=5.0, est=3.9362301369863015, details={'was_impossible': False}),
#  Prediction(uid=165720, iid=13217, r_ui=4.0, est=3.6126697674418606, details={'was_impossible': False}),
#  Prediction(uid=166041, iid=9426, r_ui=5.0, est=4.084384293436077, details={'was_impossible': False}),
#  Prediction(uid=166809, iid=3489, r_ui=3.0, est=3.399914228971443, details={'was_impossible': False}),
#  Prediction(uid=167100, iid=1542, r_ui=3.0, est=3.662900618106567, details={'was_impossible': False}),
#  Prediction(uid=167227, iid=8148, r_ui=4.0, est=3.6109558646616544, details={'was_impossible': False}),
#  Prediction(uid=167447, iid=6284, r_ui=3.0, est=3.684087463057261, details={'was_impossible': False}),
#  Prediction(uid=167447, iid=12052, r_ui=5.0, est=3.572474336283186, details={'was_impossible': False}),
#  Prediction(uid=167551, iid=12343, r_ui=4.0, est=3.395787651358132, details={'was_impossible': False}),
#  Prediction(uid=167848, iid=505, r_ui=2.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=167848, iid=17529, r_ui=2.0, est=3.476845714285714, details={'was_impossible': False}),
#  Prediction(uid=168190, iid=11266, r_ui=1.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=168190, iid=8467, r_ui=5.0, est=3.647016367554178, details={'was_impossible': False}),
#  Prediction(uid=168263, iid=11303, r_ui=3.0, est=3.3718740300472807, details={'was_impossible': False}),
#  Prediction(uid=168263, iid=12582, r_ui=4.0, est=3.922139763777718, details={'was_impossible': False}),
#  Prediction(uid=168523, iid=3048, r_ui=3.0, est=3.297217482062904, details={'was_impossible': False}),
#  Prediction(uid=168523, iid=5760, r_ui=2.0, est=3.8707222102550665, details={'was_impossible': False}),
#  Prediction(uid=170248, iid=16325, r_ui=5.0, est=3.701216131790439, details={'was_impossible': False}),
#  Prediction(uid=170441, iid=1509, r_ui=5.0, est=3.7067730726256984, details={'was_impossible': False}),
#  Prediction(uid=172229, iid=15154, r_ui=3.0, est=3.468774493714701, details={'was_impossible': False}),
#  Prediction(uid=174783, iid=1638, r_ui=2.0, est=3.6265807807312544, details={'was_impossible': False}),
#  Prediction(uid=177104, iid=1532, r_ui=1.0, est=3.0640494890974885, details={'was_impossible': False}),
#  Prediction(uid=177351, iid=457, r_ui=4.0, est=3.6447702764370336, details={'was_impossible': False}),
#  Prediction(uid=177978, iid=16313, r_ui=4.0, est=3.617597581911441, details={'was_impossible': False}),
#  Prediction(uid=178696, iid=3469, r_ui=4.0, est=3.564707025005692, details={'was_impossible': False}),
#  Prediction(uid=178860, iid=12841, r_ui=3.0, est=3.5402444876611114, details={'was_impossible': False}),
#  Prediction(uid=178886, iid=16495, r_ui=4.0, est=3.8280702731916527, details={'was_impossible': False}),
#  Prediction(uid=178886, iid=16912, r_ui=4.0, est=3.254352475247525, details={'was_impossible': False}),
#  Prediction(uid=181592, iid=12662, r_ui=2.0, est=3.486264406779661, details={'was_impossible': False}),
#  Prediction(uid=181592, iid=13458, r_ui=4.0, est=3.2429454545454544, details={'was_impossible': False}),
#  Prediction(uid=184162, iid=11214, r_ui=4.0, est=3.4316464270077702, details={'was_impossible': False}),
#  Prediction(uid=184705, iid=7644, r_ui=3.0, est=3.7710248254629857, details={'was_impossible': False}),
#  Prediction(uid=184888, iid=8107, r_ui=4.0, est=3.815692492042355, details={'was_impossible': False}),
#  Prediction(uid=187062, iid=11490, r_ui=3.0, est=3.8110085377001623, details={'was_impossible': False}),
#  Prediction(uid=187896, iid=17270, r_ui=3.0, est=3.636896923076923, details={'was_impossible': False}),
#  Prediction(uid=188613, iid=2505, r_ui=3.0, est=3.5110117519826964, details={'was_impossible': False}),
#  Prediction(uid=189887, iid=499, r_ui=3.0, est=3.3111272727272727, details={'was_impossible': False}),
#  Prediction(uid=189887, iid=3451, r_ui=3.0, est=3.676042105263158, details={'was_impossible': False}),
#  Prediction(uid=190286, iid=17136, r_ui=3.0, est=3.465911512195122, details={'was_impossible': False}),
#  Prediction(uid=190474, iid=8883, r_ui=4.0, est=3.8313455569461827, details={'was_impossible': False}),
#  Prediction(uid=190479, iid=10899, r_ui=4.0, est=3.539755730062765, details={'was_impossible': False}),
#  Prediction(uid=190479, iid=6844, r_ui=3.0, est=3.1489151886577673, details={'was_impossible': False}),
#  Prediction(uid=190547, iid=12988, r_ui=2.0, est=3.222949074640351, details={'was_impossible': False}),
#  Prediction(uid=192561, iid=11975, r_ui=5.0, est=3.6448637509695208, details={'was_impossible': False}),
#  Prediction(uid=192889, iid=13058, r_ui=3.0, est=3.735735097093819, details={'was_impossible': False}),
#  Prediction(uid=193303, iid=15755, r_ui=3.0, est=3.7108974025974026, details={'was_impossible': False}),
#  Prediction(uid=193430, iid=7779, r_ui=5.0, est=3.9966617996455067, details={'was_impossible': False}),
#  Prediction(uid=193430, iid=9740, r_ui=5.0, est=3.546587234042553, details={'was_impossible': False}),
#  Prediction(uid=193510, iid=11837, r_ui=2.0, est=3.300552130310827, details={'was_impossible': False}),
#  Prediction(uid=193838, iid=11752, r_ui=4.0, est=3.440573156484496, details={'was_impossible': False}),
#  Prediction(uid=194537, iid=16502, r_ui=3.0, est=3.5669926829268293, details={'was_impossible': False}),
#  Prediction(uid=196105, iid=9685, r_ui=3.0, est=3.299036996527613, details={'was_impossible': False}),
#  Prediction(uid=196105, iid=14918, r_ui=3.0, est=3.647553488372093, details={'was_impossible': False}),
#  Prediction(uid=197101, iid=16107, r_ui=3.0, est=3.5980853658536587, details={'was_impossible': False}),
#  Prediction(uid=197155, iid=5181, r_ui=4.0, est=3.494762900021202, details={'was_impossible': False}),
#  Prediction(uid=198000, iid=6702, r_ui=5.0, est=3.3645029713646815, details={'was_impossible': False}),
#  Prediction(uid=198251, iid=2780, r_ui=3.0, est=3.3910205172050127, details={'was_impossible': False}),
#  Prediction(uid=198655, iid=10123, r_ui=4.0, est=3.305227088700773, details={'was_impossible': False}),
#  Prediction(uid=198955, iid=3085, r_ui=3.0, est=3.1930932374869587, details={'was_impossible': False}),
#  Prediction(uid=199257, iid=15813, r_ui=2.0, est=3.2094139449755086, details={'was_impossible': False}),
#  Prediction(uid=199257, iid=10037, r_ui=3.0, est=3.480515930429494, details={'was_impossible': False}),
#  Prediction(uid=199257, iid=16608, r_ui=3.0, est=3.447541644715208, details={'was_impossible': False}),
#  Prediction(uid=199435, iid=8881, r_ui=2.0, est=3.6234654970362046, details={'was_impossible': False}),
#  Prediction(uid=200139, iid=10643, r_ui=1.0, est=3.7253822417100575, details={'was_impossible': False}),
#  Prediction(uid=200255, iid=15953, r_ui=4.0, est=3.725397303370787, details={'was_impossible': False}),
#  Prediction(uid=200551, iid=12090, r_ui=3.0, est=3.390193416915428, details={'was_impossible': False}),
#  Prediction(uid=200596, iid=595, r_ui=3.0, est=3.579438, details={'was_impossible': False}),
#  Prediction(uid=200734, iid=1800, r_ui=5.0, est=3.763416177386733, details={'was_impossible': False}),
#  Prediction(uid=200734, iid=15365, r_ui=3.0, est=3.6262298359233185, details={'was_impossible': False}),
#  Prediction(uid=201341, iid=16640, r_ui=5.0, est=3.218404444647777, details={'was_impossible': False}),
#  Prediction(uid=201663, iid=11661, r_ui=2.0, est=3.3550978723404254, details={'was_impossible': False}),
#  Prediction(uid=201663, iid=6994, r_ui=5.0, est=3.636596130241791, details={'was_impossible': False}),
#  Prediction(uid=201707, iid=15530, r_ui=4.0, est=3.7423432405206336, details={'was_impossible': False}),
#  Prediction(uid=203299, iid=10981, r_ui=3.0, est=3.6512669647058824, details={'was_impossible': False}),
#  Prediction(uid=204110, iid=2122, r_ui=4.0, est=3.6991428855841164, details={'was_impossible': False}),
#  Prediction(uid=206520, iid=16452, r_ui=4.0, est=3.798749504761777, details={'was_impossible': False}),
#  Prediction(uid=206564, iid=2528, r_ui=4.0, est=3.676042105263158, details={'was_impossible': False}),
#  Prediction(uid=206564, iid=13705, r_ui=3.0, est=3.756646220671296, details={'was_impossible': False}),
#  Prediction(uid=208435, iid=12161, r_ui=4.0, est=3.6020173485121822, details={'was_impossible': False}),
#  Prediction(uid=209494, iid=3197, r_ui=4.0, est=3.5874673052625137, details={'was_impossible': False}),
#  Prediction(uid=209494, iid=8438, r_ui=5.0, est=3.843036486642931, details={'was_impossible': False}),
#  Prediction(uid=210453, iid=12470, r_ui=4.0, est=3.6197704876737244, details={'was_impossible': False}),
#  Prediction(uid=212729, iid=13437, r_ui=4.0, est=3.6554725485316077, details={'was_impossible': False}),
#  Prediction(uid=214125, iid=14815, r_ui=4.0, est=3.548917410799969, details={'was_impossible': False}),
#  Prediction(uid=214339, iid=11022, r_ui=5.0, est=3.760822970409938, details={'was_impossible': False}),
#  Prediction(uid=214850, iid=11390, r_ui=5.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=214850, iid=5793, r_ui=5.0, est=3.7296, details={'was_impossible': False}),
#  Prediction(uid=214850, iid=12015, r_ui=2.0, est=3.393792, details={'was_impossible': False}),
#  Prediction(uid=215281, iid=5957, r_ui=5.0, est=3.34334474393531, details={'was_impossible': False}),
#  Prediction(uid=215878, iid=571, r_ui=3.0, est=3.862700334260416, details={'was_impossible': False}),
#  Prediction(uid=216359, iid=8627, r_ui=4.0, est=3.8809358490566037, details={'was_impossible': False}),
#  Prediction(uid=216359, iid=16698, r_ui=5.0, est=3.9147243243243244, details={'was_impossible': False}),
#  Prediction(uid=217306, iid=5169, r_ui=3.0, est=4.002334448275633, details={'was_impossible': False}),
#  Prediction(uid=220416, iid=15887, r_ui=5.0, est=3.4426402299645926, details={'was_impossible': False}),
#  Prediction(uid=220512, iid=3333, r_ui=3.0, est=3.1634542857142858, details={'was_impossible': False}),
#  Prediction(uid=220526, iid=16016, r_ui=3.0, est=3.3223550561797754, details={'was_impossible': False}),
#  Prediction(uid=220526, iid=11214, r_ui=2.0, est=3.442779744969415, details={'was_impossible': False}),
#  Prediction(uid=221926, iid=9415, r_ui=4.0, est=3.465589338814272, details={'was_impossible': False}),
#  Prediction(uid=221926, iid=15163, r_ui=4.0, est=3.6196647084048026, details={'was_impossible': False}),
#  Prediction(uid=222025, iid=14265, r_ui=4.0, est=3.991295901091693, details={'was_impossible': False}),
#  Prediction(uid=222458, iid=17134, r_ui=3.0, est=3.730097036144578, details={'was_impossible': False}),
#  Prediction(uid=223043, iid=426, r_ui=4.0, est=3.698024962406015, details={'was_impossible': False}),
#  Prediction(uid=223379, iid=16359, r_ui=3.0, est=3.1747636363636365, details={'was_impossible': False}),
#  Prediction(uid=223379, iid=11195, r_ui=2.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=225862, iid=3624, r_ui=4.0, est=3.9895338717270588, details={'was_impossible': False}),
#  Prediction(uid=225935, iid=14598, r_ui=5.0, est=3.703470042458432, details={'was_impossible': False}),
#  Prediction(uid=226770, iid=5227, r_ui=3.0, est=3.278904389563201, details={'was_impossible': False}),
#  Prediction(uid=226770, iid=7399, r_ui=4.0, est=3.442685168594915, details={'was_impossible': False}),
#  Prediction(uid=227799, iid=11139, r_ui=3.0, est=3.5901518985001366, details={'was_impossible': False}),
#  Prediction(uid=227799, iid=6510, r_ui=4.0, est=3.64019018393534, details={'was_impossible': False}),
#  Prediction(uid=228544, iid=187, r_ui=2.0, est=3.6854771586524535, details={'was_impossible': False}),
#  Prediction(uid=230154, iid=14909, r_ui=1.0, est=3.6798937986809483, details={'was_impossible': False}),
#  Prediction(uid=230211, iid=3860, r_ui=4.0, est=3.50624889888273, details={'was_impossible': False}),
#  Prediction(uid=230252, iid=10683, r_ui=4.0, est=3.733988571428571, details={'was_impossible': False}),
#  Prediction(uid=230252, iid=6205, r_ui=4.0, est=3.9615219512195123, details={'was_impossible': False}),
#  Prediction(uid=230265, iid=4264, r_ui=2.0, est=3.58014, details={'was_impossible': False}),
#  Prediction(uid=230393, iid=5084, r_ui=4.0, est=3.5986251865115726, details={'was_impossible': False}),
#  Prediction(uid=232877, iid=14734, r_ui=3.0, est=3.8089593897222542, details={'was_impossible': False}),
#  Prediction(uid=233761, iid=6273, r_ui=3.0, est=3.525846218223134, details={'was_impossible': False}),
#  Prediction(uid=234023, iid=16384, r_ui=4.0, est=3.9420757426960273, details={'was_impossible': False}),
#  Prediction(uid=234949, iid=2135, r_ui=4.0, est=3.54131320754717, details={'was_impossible': False}),
# ...
#  Prediction(uid=418316, iid=3624, r_ui=2.0, est=3.8455151612741982, details={'was_impossible': False}),
#  Prediction(uid=418653, iid=14848, r_ui=4.0, est=3.463250940766551, details={'was_impossible': False}),
#  Prediction(uid=419691, iid=7475, r_ui=4.0, est=3.6529479325173666, details={'was_impossible': False}),
#  Prediction(uid=420200, iid=11789, r_ui=4.0, est=3.5952264027069365, details={'was_impossible': False}),
#  Prediction(uid=420266, iid=8327, r_ui=5.0, est=4.369858345002626, details={'was_impossible': False}),
#  Prediction(uid=421562, iid=6931, r_ui=4.0, est=3.4752594840721414, details={'was_impossible': False}),
#  Prediction(uid=423167, iid=11544, r_ui=3.0, est=3.619683053196138, details={'was_impossible': False}),
#  Prediction(uid=423167, iid=13804, r_ui=3.0, est=3.6153, details={'was_impossible': False}),
#  Prediction(uid=423522, iid=662, r_ui=3.0, est=3.846087804878049, details={'was_impossible': False}),
#  Prediction(uid=423522, iid=9295, r_ui=4.0, est=3.753792, details={'was_impossible': False}),
#  Prediction(uid=424513, iid=4484, r_ui=5.0, est=3.5431145454545456, details={'was_impossible': False}),
#  Prediction(uid=424542, iid=14274, r_ui=1.0, est=3.107636951324799, details={'was_impossible': False}),
#  Prediction(uid=424825, iid=12785, r_ui=3.0, est=3.8990996722698252, details={'was_impossible': False}),
#  Prediction(uid=426362, iid=8915, r_ui=4.0, est=4.018808391608392, details={'was_impossible': False}),
#  Prediction(uid=426362, iid=10620, r_ui=3.0, est=3.6469393282829494, details={'was_impossible': False}),
#  Prediction(uid=426460, iid=5345, r_ui=3.0, est=3.6835953706255165, details={'was_impossible': False}),
#  Prediction(uid=427511, iid=16913, r_ui=5.0, est=3.751158754716981, details={'was_impossible': False}),
#  Prediction(uid=428014, iid=7863, r_ui=2.0, est=3.2813052631578947, details={'was_impossible': False}),
#  Prediction(uid=428014, iid=7416, r_ui=4.0, est=4.018344180451128, details={'was_impossible': False}),
#  Prediction(uid=428070, iid=3650, r_ui=4.0, est=3.6293391356266143, details={'was_impossible': False}),
#  Prediction(uid=428467, iid=6206, r_ui=5.0, est=3.70661692664953, details={'was_impossible': False}),
#  Prediction(uid=428558, iid=12828, r_ui=4.0, est=3.430281046101211, details={'was_impossible': False}),
#  Prediction(uid=428688, iid=15169, r_ui=3.0, est=3.559519655725655, details={'was_impossible': False}),
#  Prediction(uid=428688, iid=7150, r_ui=2.0, est=3.6439659971890697, details={'was_impossible': False}),
#  Prediction(uid=429260, iid=10055, r_ui=2.0, est=3.56256, details={'was_impossible': False}),
#  Prediction(uid=429260, iid=11405, r_ui=2.0, est=3.3336705882352944, details={'was_impossible': False}),
#  Prediction(uid=429876, iid=457, r_ui=5.0, est=3.800486239174856, details={'was_impossible': False}),
#  Prediction(uid=430318, iid=501, r_ui=4.0, est=3.6726540837336996, details={'was_impossible': False}),
#  Prediction(uid=432259, iid=12617, r_ui=4.0, est=3.603228157851861, details={'was_impossible': False}),
#  Prediction(uid=432427, iid=6475, r_ui=2.0, est=3.646049338219464, details={'was_impossible': False}),
#  Prediction(uid=433126, iid=10493, r_ui=3.0, est=3.469431707317073, details={'was_impossible': False}),
#  Prediction(uid=433641, iid=3936, r_ui=4.0, est=3.4177988688538243, details={'was_impossible': False}),
#  Prediction(uid=433868, iid=9635, r_ui=5.0, est=3.311696838195827, details={'was_impossible': False}),
#  Prediction(uid=435429, iid=17308, r_ui=4.0, est=3.4776207541322313, details={'was_impossible': False}),
#  Prediction(uid=436122, iid=6816, r_ui=3.0, est=3.559032299877449, details={'was_impossible': False}),
#  Prediction(uid=437182, iid=4064, r_ui=5.0, est=3.391412071859736, details={'was_impossible': False}),
#  Prediction(uid=437239, iid=12275, r_ui=4.0, est=3.56256, details={'was_impossible': False}),
#  Prediction(uid=437239, iid=6824, r_ui=3.0, est=3.733988571428571, details={'was_impossible': False}),
#  Prediction(uid=437371, iid=10981, r_ui=5.0, est=3.6866117647058823, details={'was_impossible': False}),
#  Prediction(uid=437371, iid=3371, r_ui=4.0, est=3.9435826123843922, details={'was_impossible': False}),
#  Prediction(uid=437485, iid=16793, r_ui=3.0, est=3.9236852459016394, details={'was_impossible': False}),
#  Prediction(uid=437586, iid=2904, r_ui=5.0, est=3.527358536585366, details={'was_impossible': False}),
#  Prediction(uid=437586, iid=10527, r_ui=2.0, est=3.2742051012046933, details={'was_impossible': False}),
#  Prediction(uid=437784, iid=1759, r_ui=5.0, est=3.733988571428571, details={'was_impossible': False}),
#  Prediction(uid=437784, iid=16199, r_ui=4.0, est=3.5970947368421053, details={'was_impossible': False}),
#  Prediction(uid=438733, iid=9786, r_ui=5.0, est=3.5940534949792986, details={'was_impossible': False}),
#  Prediction(uid=438733, iid=6631, r_ui=3.0, est=3.2504980751319703, details={'was_impossible': False}),
#  Prediction(uid=439922, iid=7179, r_ui=5.0, est=3.819171179742529, details={'was_impossible': False}),
#  Prediction(uid=440398, iid=2594, r_ui=3.0, est=3.17112, details={'was_impossible': False}),
#  Prediction(uid=440398, iid=13959, r_ui=4.0, est=3.54612, details={'was_impossible': False}),
#  Prediction(uid=440463, iid=9458, r_ui=4.0, est=3.458742857142857, details={'was_impossible': False}),
#  Prediction(uid=441196, iid=13748, r_ui=5.0, est=3.618866412302099, details={'was_impossible': False}),
#  Prediction(uid=441361, iid=13813, r_ui=4.0, est=3.7170270407796036, details={'was_impossible': False}),
#  Prediction(uid=442924, iid=5807, r_ui=4.0, est=3.56323706137908, details={'was_impossible': False}),
#  Prediction(uid=442963, iid=15114, r_ui=2.0, est=3.5794180393749997, details={'was_impossible': False}),
#  Prediction(uid=444085, iid=7718, r_ui=3.0, est=3.565478570761501, details={'was_impossible': False}),
#  Prediction(uid=445339, iid=2452, r_ui=5.0, est=4.451047127612407, details={'was_impossible': False}),
#  Prediction(uid=445339, iid=7331, r_ui=3.0, est=3.4688953528731936, details={'was_impossible': False}),
#  Prediction(uid=446693, iid=3414, r_ui=1.0, est=3.7407808414634145, details={'was_impossible': False}),
#  Prediction(uid=447008, iid=15409, r_ui=5.0, est=3.761260759960649, details={'was_impossible': False}),
#  Prediction(uid=447759, iid=980, r_ui=5.0, est=3.7875824015878266, details={'was_impossible': False}),
#  Prediction(uid=447759, iid=12300, r_ui=5.0, est=3.772276064954163, details={'was_impossible': False}),
#  Prediction(uid=447759, iid=3260, r_ui=5.0, est=3.7875824015878266, details={'was_impossible': False}),
#  Prediction(uid=447836, iid=14404, r_ui=3.0, est=3.7792431113764198, details={'was_impossible': False}),
#  Prediction(uid=447836, iid=7331, r_ui=5.0, est=3.514149892821042, details={'was_impossible': False}),
#  Prediction(uid=448155, iid=15057, r_ui=4.0, est=3.538376047651467, details={'was_impossible': False}),
#  Prediction(uid=449155, iid=3638, r_ui=2.0, est=3.582020809248555, details={'was_impossible': False}),
#  Prediction(uid=449155, iid=10436, r_ui=4.0, est=3.785728666786529, details={'was_impossible': False}),
#  Prediction(uid=449597, iid=5582, r_ui=5.0, est=4.430219132691185, details={'was_impossible': False}),
#  Prediction(uid=449597, iid=5154, r_ui=5.0, est=3.5579880228456786, details={'was_impossible': False}),
#  Prediction(uid=452299, iid=1890, r_ui=5.0, est=3.7046709677419356, details={'was_impossible': False}),
#  Prediction(uid=452299, iid=171, r_ui=3.0, est=3.6997463414634146, details={'was_impossible': False}),
#  Prediction(uid=454171, iid=7193, r_ui=5.0, est=4.343448, details={'was_impossible': False}),
#  Prediction(uid=454171, iid=15114, r_ui=4.0, est=3.5879593220338983, details={'was_impossible': False}),
#  Prediction(uid=454329, iid=14770, r_ui=2.0, est=3.5013631557005187, details={'was_impossible': False}),
#  Prediction(uid=455024, iid=10778, r_ui=3.0, est=3.8263313083192303, details={'was_impossible': False}),
#  Prediction(uid=455149, iid=5582, r_ui=5.0, est=4.3349592913751795, details={'was_impossible': False}),
#  Prediction(uid=455323, iid=2395, r_ui=5.0, est=3.6084041006246546, details={'was_impossible': False}),
#  Prediction(uid=457302, iid=14584, r_ui=1.0, est=3.566478376990016, details={'was_impossible': False}),
#  Prediction(uid=458143, iid=10612, r_ui=5.0, est=3.8083107943963075, details={'was_impossible': False}),
#  Prediction(uid=458475, iid=14538, r_ui=4.0, est=3.7376802823509423, details={'was_impossible': False}),
#  Prediction(uid=458475, iid=3222, r_ui=3.0, est=3.3550978723404254, details={'was_impossible': False}),
#  Prediction(uid=459462, iid=1962, r_ui=5.0, est=3.7310865860101434, details={'was_impossible': False}),
#  Prediction(uid=460492, iid=14039, r_ui=5.0, est=3.9180467532467533, details={'was_impossible': False}),
#  Prediction(uid=460492, iid=14334, r_ui=3.0, est=3.418927659574468, details={'was_impossible': False}),
#  Prediction(uid=460980, iid=11781, r_ui=5.0, est=4.140696258143904, details={'was_impossible': False}),
#  Prediction(uid=461075, iid=16758, r_ui=1.0, est=3.2466859740259744, details={'was_impossible': False}),
#  Prediction(uid=461110, iid=13614, r_ui=5.0, est=3.8504265893920966, details={'was_impossible': False}),
#  Prediction(uid=462171, iid=8325, r_ui=2.0, est=3.3959146208048794, details={'was_impossible': False}),
#  Prediction(uid=465238, iid=7627, r_ui=2.0, est=3.063019156824566, details={'was_impossible': False}),
#  Prediction(uid=465436, iid=7048, r_ui=3.0, est=3.411553246753247, details={'was_impossible': False}),
#  Prediction(uid=465436, iid=9756, r_ui=4.0, est=3.2934066114053886, details={'was_impossible': False}),
#  Prediction(uid=466151, iid=12476, r_ui=4.0, est=3.34960458280543, details={'was_impossible': False}),
#  Prediction(uid=466170, iid=1255, r_ui=2.0, est=3.723996524172945, details={'was_impossible': False}),
#  Prediction(uid=466170, iid=12184, r_ui=5.0, est=4.135089487437355, details={'was_impossible': False}),
#  Prediction(uid=467596, iid=1553, r_ui=5.0, est=3.660621726078799, details={'was_impossible': False}),
#  Prediction(uid=468508, iid=17513, r_ui=4.0, est=3.5251320981507823, details={'was_impossible': False}),
#  Prediction(uid=468579, iid=8585, r_ui=3.0, est=3.506951473645849, details={'was_impossible': False}),
#  Prediction(uid=468584, iid=4262, r_ui=5.0, est=3.8624937583231587, details={'was_impossible': False}),
#  Prediction(uid=471177, iid=5104, r_ui=3.0, est=3.377867653657336, details={'was_impossible': False}),
#  Prediction(uid=471880, iid=12501, r_ui=4.0, est=4.03295225267415, details={'was_impossible': False}),
#  Prediction(uid=472052, iid=3999, r_ui=2.0, est=3.662794115176988, details={'was_impossible': False}),
#  Prediction(uid=472309, iid=11064, r_ui=5.0, est=3.8994626609270813, details={'was_impossible': False}),
#  Prediction(uid=475253, iid=17064, r_ui=4.0, est=3.6096803090727816, details={'was_impossible': False}),
#  Prediction(uid=476470, iid=4951, r_ui=4.0, est=3.8445070930214826, details={'was_impossible': False}),
#  Prediction(uid=476470, iid=1901, r_ui=4.0, est=3.7071036144578313, details={'was_impossible': False}),
#  Prediction(uid=476512, iid=3416, r_ui=3.0, est=3.6815826915258505, details={'was_impossible': False}),
#  Prediction(uid=476669, iid=3165, r_ui=3.0, est=3.849955321135394, details={'was_impossible': False}),
#  Prediction(uid=476695, iid=11038, r_ui=5.0, est=3.8832198181818183, details={'was_impossible': False}),
#  Prediction(uid=479092, iid=8717, r_ui=4.0, est=3.721730504379342, details={'was_impossible': False}),
#  Prediction(uid=479924, iid=15836, r_ui=5.0, est=3.891631818181818, details={'was_impossible': False}),
#  Prediction(uid=479932, iid=13582, r_ui=3.0, est=3.7089771446076676, details={'was_impossible': False}),
#  Prediction(uid=479932, iid=15922, r_ui=5.0, est=3.935937267080745, details={'was_impossible': False}),
#  Prediction(uid=480115, iid=12014, r_ui=3.0, est=3.2394802461855168, details={'was_impossible': False}),
#  Prediction(uid=481862, iid=15234, r_ui=4.0, est=3.2660756756756757, details={'was_impossible': False}),
#  Prediction(uid=481980, iid=6978, r_ui=3.0, est=3.4343064198504445, details={'was_impossible': False}),
#  Prediction(uid=483483, iid=5614, r_ui=4.0, est=3.5767005405405405, details={'was_impossible': False}),
#  Prediction(uid=483483, iid=3917, r_ui=4.0, est=3.739541116751269, details={'was_impossible': False}),
#  Prediction(uid=483483, iid=313, r_ui=3.0, est=3.4450197424892703, details={'was_impossible': False}),
#  Prediction(uid=483851, iid=14126, r_ui=1.0, est=3.2670285085965616, details={'was_impossible': False}),
#  Prediction(uid=483851, iid=3551, r_ui=4.0, est=3.658342921013413, details={'was_impossible': False}),
#  Prediction(uid=484044, iid=1810, r_ui=4.0, est=3.778249373436281, details={'was_impossible': False}),
#  Prediction(uid=485152, iid=6134, r_ui=2.0, est=3.56840149977792, details={'was_impossible': False}),
#  Prediction(uid=485175, iid=17215, r_ui=3.0, est=3.811298595552355, details={'was_impossible': False}),
#  Prediction(uid=485175, iid=12582, r_ui=4.0, est=3.971444865818534, details={'was_impossible': False}),
#  Prediction(uid=485601, iid=17104, r_ui=3.0, est=3.3489482984207344, details={'was_impossible': False}),
#  Prediction(uid=485601, iid=4888, r_ui=3.0, est=3.681490790135051, details={'was_impossible': False}),
#  Prediction(uid=485931, iid=11496, r_ui=2.0, est=3.6127579591836736, details={'was_impossible': False}),
#  Prediction(uid=486055, iid=16765, r_ui=2.0, est=3.7741915615100456, details={'was_impossible': False}),
#  Prediction(uid=486915, iid=6720, r_ui=2.0, est=3.9648887095949106, details={'was_impossible': False}),
#  Prediction(uid=487230, iid=5939, r_ui=3.0, est=3.2249373175126115, details={'was_impossible': False}),
#  Prediction(uid=487558, iid=10894, r_ui=3.0, est=3.4413784615384615, details={'was_impossible': False}),
#  Prediction(uid=487558, iid=12539, r_ui=4.0, est=3.449903436478265, details={'was_impossible': False}),
#  Prediction(uid=488119, iid=11740, r_ui=5.0, est=3.5707724675324677, details={'was_impossible': False}),
#  Prediction(uid=488477, iid=7624, r_ui=4.0, est=3.8571033029197968, details={'was_impossible': False}),
#  Prediction(uid=489454, iid=14889, r_ui=3.0, est=3.576282486810107, details={'was_impossible': False}),
#  Prediction(uid=490057, iid=13934, r_ui=4.0, est=3.5607672870826255, details={'was_impossible': False}),
#  Prediction(uid=491331, iid=10509, r_ui=3.0, est=3.4556340376176995, details={'was_impossible': False}),
#  Prediction(uid=491513, iid=8595, r_ui=3.0, est=3.5838545454545456, details={'was_impossible': False}),
#  Prediction(uid=491513, iid=11004, r_ui=4.0, est=3.447490909090909, details={'was_impossible': False}),
#  Prediction(uid=491531, iid=16236, r_ui=5.0, est=3.547408244103847, details={'was_impossible': False}),
#  Prediction(uid=491531, iid=825, r_ui=3.0, est=3.255575084334047, details={'was_impossible': False}),
#  Prediction(uid=492035, iid=7745, r_ui=4.0, est=4.087551691329338, details={'was_impossible': False}),
#  Prediction(uid=492035, iid=14550, r_ui=4.0, est=4.585060296547436, details={'was_impossible': False}),
#  Prediction(uid=492394, iid=7131, r_ui=3.0, est=3.5626958077758997, details={'was_impossible': False}),
#  Prediction(uid=493263, iid=8019, r_ui=5.0, est=3.5118629991335992, details={'was_impossible': False}),
#  Prediction(uid=494200, iid=6190, r_ui=5.0, est=3.961742300634133, details={'was_impossible': False}),
#  Prediction(uid=495800, iid=4260, r_ui=2.0, est=3.5011153323705315, details={'was_impossible': False}),
#  Prediction(uid=496436, iid=11661, r_ui=1.0, est=3.3932674154876334, details={'was_impossible': False}),
#  Prediction(uid=496794, iid=2109, r_ui=3.0, est=3.507535662834499, details={'was_impossible': False}),
#  Prediction(uid=497196, iid=10358, r_ui=1.0, est=2.8934941191809163, details={'was_impossible': False}),
#  Prediction(uid=497900, iid=12244, r_ui=2.0, est=3.2099942824633767, details={'was_impossible': False}),
#  Prediction(uid=498129, iid=7193, r_ui=4.0, est=4.392855838839442, details={'was_impossible': False}),
#  Prediction(uid=498129, iid=1145, r_ui=4.0, est=3.072216528971763, details={'was_impossible': False}),
#  ...]

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.8473
# 0.8473334647775006

# %%
accuracy.rmse(predictions, verbose=True)
# Out:
# RMSE: 1.0416
# 1.0415582301746527

# %% [markdown]
# # First Simple Model

# %%
#instance of SVD algorithm, fit using training set
svd = SVD(random_state=1)
svd.fit(train_sr)

#predicting based on validation set
preds = svd.test(val_sr)

# %%
#mae
accuracy.mae(preds)
# Out:
# MAE:  0.8436
# 0.8436178242415615

# %%
#rmse score
accuracy.rmse(preds)
# Out:
# RMSE: 1.0413
# 1.0412625996204237

# %% [markdown]
# # Tuning First Simple Model
#
# This model performed negligably better. Tuning model:

# %%
crossval = cross_validate(svd, train_data, measures=['MAE','RMSE'], cv=5, verbose=True)
# Out:
# Evaluating MAE, RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# MAE (testset)     0.8429  0.8431  0.8557  0.8443  0.8525  0.8477  0.0053
# RMSE (testset)    1.0385  1.0414  1.0515  1.0431  1.0512  1.0451  0.0053
# Fit time          0.68    0.67    0.67    0.71    0.68    0.68    0.02
# Test time         0.06    0.17    0.07    0.16    0.05    0.10    0.05

# %% [markdown]
# references:
# https://towardsdatascience.com/build-a-recommender-system-yelp-rating-prediction-example-collaborative-filtering-28a6e48a8cc
#
# surprise tutorialL
# https://towardsdatascience.com/building-and-testing-recommender-systems-with-surprise-step-by-step-d4ba702ef80b
