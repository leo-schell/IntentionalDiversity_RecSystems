# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from scipy.sparse import csr_matrix

# %%
#notify me when a long running cell is complete
# %load_ext jupyternotify
import time

# %%
data = pd.read_csv('data/final_df_500k.csv')
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#     mid  cust_id  rating      r_date  r_year  r_fiscQ  m_decade  m_avg_rating
# 0  3113   510180     3.0  1999-12-12    1999        4         4      3.152381  \
# 1  3113  1259176     4.0  2000-11-10    2000        4         4      3.152381
# 2  3113   739622     4.0  2001-07-15    2001        3         4      3.152381
# 3  3113  1709239     3.0  2001-09-10    2001        4         4      3.152381
# 4  3113  2618750     3.0  2001-10-11    2001        4         4      3.152381
#
#    m_quality
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   mid           500000 non-null  int64
#  1   cust_id       500000 non-null  int64
#  2   rating        500000 non-null  float64
#  3   r_date        500000 non-null  object
#  4   r_year        500000 non-null  int64
#  5   r_fiscQ       500000 non-null  int64
#  6   m_decade      500000 non-null  int64
#  7   m_avg_rating  500000 non-null  float64
#  8   m_quality     500000 non-null  int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 34.3+ MB

# %%
data['r_date'] = data['r_date'].astype('datetime64[ns]')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   mid           500000 non-null  int64
#  1   cust_id       500000 non-null  int64
#  2   rating        500000 non-null  float64
#  3   r_date        500000 non-null  datetime64[ns]
#  4   r_year        500000 non-null  int64
#  5   r_fiscQ       500000 non-null  int64
#  6   m_decade      500000 non-null  int64
#  7   m_avg_rating  500000 non-null  float64
#  8   m_quality     500000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6)
# memory usage: 34.3 MB

# %%
data = data.sort_values(by=['r_date'])
data
# Out:
#           mid  cust_id  rating     r_date  r_year  r_fiscQ  m_decade
# 0        3113   510180     3.0 1999-12-12    1999        4         4  \
# 105     11242   830363     3.0 1999-12-21    1999        4         3
# 316     14574   882798     3.0 1999-12-30    1999        4         4
# 833     17563  2114455     3.0 1999-12-30    1999        4         1
# 878       953  1572303     3.0 1999-12-30    1999        4         1
# ...       ...      ...     ...        ...     ...      ...       ...
# 102795   2965  1271554     4.0 2005-12-31    2005        4         0
# 481441   8393  1236402     4.0 2005-12-31    2005        4         5
# 227426   5402   162834     3.0 2005-12-31    2005        4         2
# 226787   6237  1271554     3.0 2005-12-31    2005        4         3
# 499999  14141   899183     3.0 2005-12-31    2005        4         4
#
#         m_avg_rating  m_quality
# 0           3.152381          2
# 105         3.821138          3
# 316         3.444874          3
# 833         3.711111          3
# 878         3.651163          3
# ...              ...        ...
# 102795      3.940000          4
# 481441      3.773723          3
# 227426      3.666667          3
# 226787      3.396226          2
# 499999      3.000000          2
#
# [500000 rows x 9 columns]

# %%
scaler = MinMaxScaler()
data[['r_scaled']] = scaler.fit_transform(data[['rating']])
data.head()
# Out:
#        mid  cust_id  rating     r_date  r_year  r_fiscQ  m_decade
# 0     3113   510180     3.0 1999-12-12    1999        4         4  \
# 105  11242   830363     3.0 1999-12-21    1999        4         3
# 316  14574   882798     3.0 1999-12-30    1999        4         4
# 833  17563  2114455     3.0 1999-12-30    1999        4         1
# 878    953  1572303     3.0 1999-12-30    1999        4         1
#
#      m_avg_rating  m_quality  r_scaled
# 0        3.152381          2       0.5
# 105      3.821138          3       0.5
# 316      3.444874          3       0.5
# 833      3.711111          3       0.5
# 878      3.651163          3       0.5

# %%
data['r_scaled'].mean()
# Out:
# 0.651175

# %%
data_pivot = data.pivot(index='cust_id', columns='mid', values='rating')
data_pivot.head()
# Out:
# /var/folders/xc/4fn08svj2dgdk_3wj3xkp_rr0000gn/T/ipykernel_2027/1264852765.py:1: PerformanceWarning: The following operation may generate 3114883968 cells in the resulting pandas object.
#   data_pivot = data.pivot(index='cust_id', columns='mid', values='rating')
# mid      1      2      3      5      6      8      9      13     15     16
# cust_id
# 6          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  \
# 7          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 42         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 79         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# mid      ...  17761  17762  17763  17764  17765  17766  17767  17768  17769
# cust_id  ...
# 6        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  \
# 7        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8        ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 42       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 79       ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# mid      17770
# cust_id
# 6          NaN
# 7          NaN
# 8          NaN
# 42         NaN
# 79         NaN
#
# [5 rows x 14384 columns]

# %%
data_pivot = data_pivot.fillna(.65)
data_pivot.head()

# %%
data_pivot[79].info()

# %%
data_scaled

# %%
np.nan_to_num(data_scaled, nan=.5)

# %%
# %notify

# %% [markdown]
# # Train  Test Split
#
# temporal split

# %%
testsize = round(len(data) * 0.2)
testsize

# %%
#split based on time
df_train = data[:-(2*testsize)]
df_val = data[-(2*testsize):-testsize]
df_test = data[-testsize:]

# %%
df_train

# %%
df_val

# %%
df_test

# %% [markdown]
# # Train

# %%
f,ax = plt.subplots()

sns.scatterplot(x=X[:,0], y=X[:,1], ax=ax, hue=y, palette='colorblind')
ax.get_legend().remove()

# %%
train_table = df_train.pivot(index='cust_id', columns='mid', values='rating')
train_table.head()

# %%
train_table = scaler.transform(train_table)

# %%
np.nan_to_num(train_table, nan=.5)

# %%
# %notify

# %% [markdown]
# # Val

# %%
val_table = df_val.pivot(index='cust_id', columns='mid', values='rating')
val_table.head()

# %% [markdown]
# # Test

# %%
test_table = df_test.pivot(index='cust_id', columns='mid', values='rating')
test_table.head()

# %%
train_scaled = scaler.fit_transform(train_table)

# %%
train_scaled = train_scaled.fillna(.5)
train_scaled

# %%
# %notify

# %%
# %notify
