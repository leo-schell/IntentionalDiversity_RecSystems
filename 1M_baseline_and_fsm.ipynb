# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import os
from surprise import Dataset
from surprise import Reader
from surprise import BaselineOnly
from surprise import accuracy
from surprise import SVD
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise.model_selection import RandomizedSearchCV

# %%
#notify me when a long running cell is complete
# %load_ext jupyternotify
import time

# %%
data = pd.read_csv('data/1mdf.csv')

#only columns relevant to surprise
data = data.drop(['m_decade'], axis=1)

#for split
data['r_date'] = data['r_date'].astype('datetime64[ns]')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   mid      1000000 non-null  int64
#  1   cust_id  1000000 non-null  int64
#  2   rating   1000000 non-null  float64
#  3   r_date   1000000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 30.5 MB

# %%
#reorder for suprise
data = data[['cust_id', 'mid', 'rating', 'r_date']]
data.head()
# Out:
#    cust_id   mid  rating     r_date
# 0   510180  3113     3.0 1999-12-12
# 1  1589382  3113     4.0 2000-03-11
# 2  1878798  3113     2.0 2000-08-08
# 3  1259176  3113     4.0 2000-11-10
# 4   873369  3113     3.0 2000-11-20

# %% [markdown]
# # Train/Test Split: out of time approach

# %%
testsize = round(len(data) * 0.2)
testsize
# Out:
# 200000

# %%
data.groupby('cust_id')['rating'].count().sort_values(ascending=False)
# Out:
# cust_id
# 305344     192
# 2439493    161
# 1664010    155
# 387418     154
# 2118461    154
#           ...
# 1933293      1
# 834542       1
# 834484       1
# 461356       1
# 360932       1
# Name: rating, Length: 290022, dtype: int64

# %% [markdown]
# This would work better with more data and less users who don't only vote once

# %%
data = data.sort_values(by=['cust_id'])
data
# Out:
#         cust_id    mid  rating     r_date
# 7258          6  13462     3.0 2004-11-13
# 361326        6   5112     3.0 2005-01-12
# 251023        6   6339     1.0 2004-09-25
# 173559        6  15105     3.0 2005-12-04
# 458082        6  14112     3.0 2005-10-26
# ...         ...    ...     ...        ...
# 829084  2649426  17207     3.0 2004-05-11
# 952614  2649426   5909     3.0 2005-07-13
# 756283  2649426    111     4.0 2004-05-25
# 458974  2649429  16792     5.0 2002-06-06
# 805510  2649429   7852     5.0 2004-05-17
#
# [1000000 rows x 4 columns]

# %%
#splitting data into 3 groups based on how many reviews they've given
for cust in data['cust_id'].unique():
    i = data.index[data['cust_id'] == cust]
    
    #if more than 2, the final review will be in holdout, 2nd to last will be in the test
    if len(i)> 2:
        data.loc[i[-1], 'split'] = 3
        data.loc[i[-2], 'split'] = 2
        data.loc[i[:-2], 'split'] = 1
        
    #if 2, the final review will be in the test
    if len(i) == 2:
        data.loc[i[-1], 'split'] = 2
        data.loc[i[0], 'split'] = 1
        
    #everyone with one review gets a linear temporal split
    else:
        data.loc[i[0], 'split'] = 1
        
holdout = data[(data['split'] == 3)]
test = data[(data['split'] == 2)]
train = data[(data['split'] == 1 )]

# %%
# %notify

# %%
print('holdout:', holdout.shape)
print('test:', test.shape)
print('train:', train.shape)
# Out:
# holdout: (128183, 5)
# test: (185571, 5)
# train: (686246, 5)

# %%
#sort vals by date, prep to split linearly
train = train.sort_values(by=['r_date'])
train
# Out:
#         cust_id    mid  rating     r_date  split
# 0        510180   3113     3.0 1999-12-12    1.0
# 731      830363  11242     3.0 1999-12-21    1.0
# 974     1435350   8327     5.0 1999-12-27    1.0
# 4106    1267764   4670     3.0 1999-12-30    1.0
# 4883     882798  16438     4.0 1999-12-30    1.0
# ...         ...    ...     ...        ...    ...
# 678419   330800   5495     3.0 2005-12-31    1.0
# 747707  2536322   5919     4.0 2005-12-31    1.0
# 203960  2376301   2395     5.0 2005-12-31    1.0
# 427098  1125499   9591     4.0 2005-12-31    1.0
# 848549  2136204  12126     3.0 2005-12-31    1.0
#
# [686246 rows x 5 columns]

# %%
#adding only the end of training set to test
holdout2 = train[-(testsize -len(holdout)):]
holdout = pd.concat([holdout, holdout2])

#200k
print(holdout.shape)

#sanity check
holdout = holdout.sort_values(by=['r_date'])
holdout
# Out:
# (200000, 5)
#         cust_id    mid  rating     r_date  split
# 6318    2114455  17563     3.0 1999-12-30    3.0
# 3651     872963   1642     4.0 1999-12-30    3.0
# 14361   1192830  16788     4.0 2000-01-05    3.0
# 14511   1426824   3870     2.0 2000-01-05    3.0
# 13315   1972971  17560     3.0 2000-01-05    3.0
# ...         ...    ...     ...        ...    ...
# 14810     28205  10371     4.0 2005-12-31    1.0
# 995954  2235350   8993     5.0 2005-12-31    1.0
# 771825   361630  17149     1.0 2005-12-31    1.0
# 81713   1662699  16242     4.0 2005-12-31    1.0
# 848549  2136204  12126     3.0 2005-12-31    1.0
#
# [200000 rows x 5 columns]

# %%
#remove holdout rows
train = train.loc[~train.index.isin(holdout.index)]
train.shape
# Out:
# (614429, 5)

# %%
#fill in test with random samples
test1 = train.sample(n=(200000-len(test)), replace=False, random_state=1)
test = pd.concat([test, test1])

#200k
test.shape
# Out:
# (200000, 5)

# %%
train = train.loc[~train.index.isin(test1.index)]
train.shape
# Out:
# (600000, 5)

# %% [markdown]
# # Baseline using Surprise

# %%
reader = Reader(rating_scale=(1,5))

# %%
train_data = Dataset.load_from_df(train[['cust_id','mid','rating']], reader)
test_data = Dataset.load_from_df(test[['cust_id','mid','rating']], reader)
ho_data = Dataset.load_from_df(holdout[['cust_id','mid','rating']], reader)

# %%
#correct surprise dataset format
train_sr = train_data.build_full_trainset()


test_sr1 = test_data.build_full_trainset()
test_sr = test_sr1.build_testset()

ho_sr1 = ho_data.build_full_trainset()
ho_sr = ho_sr1.build_testset()

# %%
#using stochastic gradient descent bc that is used in svd
#20 epochs because that is the svd default
bsl_options = {'method': 'sgd', 'n_epochs':20}
bias_baseline = BaselineOnly(bsl_options)
bias_baseline.fit(train_sr)
predictions = bias_baseline.test(test_sr)
# Out:
# Estimating biases using sgd...

# %%
predictions
# Out:
# [Prediction(uid=6, iid=10730, r_ui=5.0, est=3.1208968797817223, details={'was_impossible': False}),
#  Prediction(uid=7, iid=16107, r_ui=5.0, est=4.3677359140032355, details={'was_impossible': False}),
#  Prediction(uid=8, iid=3936, r_ui=4.0, est=3.1803894138967057, details={'was_impossible': False}),
#  Prediction(uid=42, iid=13887, r_ui=5.0, est=3.749547164508022, details={'was_impossible': False}),
#  Prediction(uid=79, iid=15116, r_ui=5.0, est=3.9787189819271473, details={'was_impossible': False}),
#  Prediction(uid=97, iid=13809, r_ui=3.0, est=3.366184849667852, details={'was_impossible': False}),
#  Prediction(uid=134, iid=14759, r_ui=5.0, est=4.0620875578490265, details={'was_impossible': False}),
#  Prediction(uid=169, iid=12293, r_ui=4.0, est=4.534512520888368, details={'was_impossible': False}),
#  Prediction(uid=169, iid=3433, r_ui=4.0, est=3.3785512523683017, details={'was_impossible': False}),
#  Prediction(uid=188, iid=17560, r_ui=4.0, est=3.736189666873589, details={'was_impossible': False}),
#  Prediction(uid=192, iid=15715, r_ui=4.0, est=3.5130846137768597, details={'was_impossible': False}),
#  Prediction(uid=195, iid=14550, r_ui=5.0, est=4.582279480464076, details={'was_impossible': False}),
#  Prediction(uid=199, iid=329, r_ui=5.0, est=3.822573744243952, details={'was_impossible': False}),
#  Prediction(uid=201, iid=11149, r_ui=3.0, est=3.138251686725617, details={'was_impossible': False}),
#  Prediction(uid=231, iid=16765, r_ui=4.0, est=3.6384264259407684, details={'was_impossible': False}),
#  Prediction(uid=242, iid=16082, r_ui=4.0, est=3.5674843235718394, details={'was_impossible': False}),
#  Prediction(uid=250, iid=10042, r_ui=3.0, est=4.4496010720618, details={'was_impossible': False}),
#  Prediction(uid=265, iid=14780, r_ui=3.0, est=3.8709662755728376, details={'was_impossible': False}),
#  Prediction(uid=266, iid=10359, r_ui=3.0, est=3.3101807888321084, details={'was_impossible': False}),
#  Prediction(uid=268, iid=11390, r_ui=5.0, est=4.061067899005419, details={'was_impossible': False}),
#  Prediction(uid=283, iid=13748, r_ui=3.0, est=3.4584348163677947, details={'was_impossible': False}),
#  Prediction(uid=291, iid=9525, r_ui=4.0, est=3.7219929625404693, details={'was_impossible': False}),
#  Prediction(uid=296, iid=17328, r_ui=5.0, est=4.061114016078945, details={'was_impossible': False}),
#  Prediction(uid=298, iid=10730, r_ui=3.0, est=3.2772448144592765, details={'was_impossible': False}),
#  Prediction(uid=301, iid=16790, r_ui=5.0, est=3.2496261085123135, details={'was_impossible': False}),
#  Prediction(uid=302, iid=15107, r_ui=3.0, est=3.970297421578939, details={'was_impossible': False}),
#  Prediction(uid=304, iid=15182, r_ui=3.0, est=3.1927986748721144, details={'was_impossible': False}),
#  Prediction(uid=383, iid=6205, r_ui=4.0, est=4.029231761378152, details={'was_impossible': False}),
#  Prediction(uid=384, iid=1703, r_ui=3.0, est=3.8461647370333707, details={'was_impossible': False}),
#  Prediction(uid=462, iid=1102, r_ui=2.0, est=3.3161758411721793, details={'was_impossible': False}),
#  Prediction(uid=477, iid=4590, r_ui=3.0, est=3.4194257853407937, details={'was_impossible': False}),
#  Prediction(uid=481, iid=11614, r_ui=5.0, est=3.7373285687065496, details={'was_impossible': False}),
#  Prediction(uid=527, iid=13595, r_ui=3.0, est=3.031445003998894, details={'was_impossible': False}),
#  Prediction(uid=544, iid=1700, r_ui=5.0, est=3.6240346737948483, details={'was_impossible': False}),
#  Prediction(uid=550, iid=3684, r_ui=5.0, est=4.051091693951375, details={'was_impossible': False}),
#  Prediction(uid=561, iid=3274, r_ui=3.0, est=3.6680870256777784, details={'was_impossible': False}),
#  Prediction(uid=592, iid=5807, r_ui=3.0, est=3.623527747626665, details={'was_impossible': False}),
#  Prediction(uid=596, iid=10982, r_ui=3.0, est=4.367177036072155, details={'was_impossible': False}),
#  Prediction(uid=602, iid=13795, r_ui=4.0, est=3.559487708663203, details={'was_impossible': False}),
#  Prediction(uid=609, iid=5069, r_ui=4.0, est=4.043812677161658, details={'was_impossible': False}),
#  Prediction(uid=614, iid=15816, r_ui=5.0, est=3.6976049178077948, details={'was_impossible': False}),
#  Prediction(uid=663, iid=10947, r_ui=5.0, est=4.281593751891818, details={'was_impossible': False}),
#  Prediction(uid=664, iid=2862, r_ui=5.0, est=4.375707150016529, details={'was_impossible': False}),
#  Prediction(uid=684, iid=8512, r_ui=5.0, est=3.3820622483102345, details={'was_impossible': False}),
#  Prediction(uid=688, iid=14240, r_ui=5.0, est=4.4428521225297715, details={'was_impossible': False}),
#  Prediction(uid=695, iid=4302, r_ui=4.0, est=3.752639619335529, details={'was_impossible': False}),
#  Prediction(uid=735, iid=12974, r_ui=5.0, est=4.015971784106424, details={'was_impossible': False}),
#  Prediction(uid=750, iid=1566, r_ui=4.0, est=3.3994274484224607, details={'was_impossible': False}),
#  Prediction(uid=756, iid=886, r_ui=2.0, est=3.8996847336953486, details={'was_impossible': False}),
#  Prediction(uid=769, iid=3730, r_ui=3.0, est=3.700003980553038, details={'was_impossible': False}),
#  Prediction(uid=785, iid=16377, r_ui=4.0, est=4.54110154478364, details={'was_impossible': False}),
#  Prediction(uid=787, iid=9471, r_ui=3.0, est=3.713626007274506, details={'was_impossible': False}),
#  Prediction(uid=788, iid=12155, r_ui=3.0, est=3.669515981003409, details={'was_impossible': False}),
#  Prediction(uid=798, iid=5418, r_ui=5.0, est=3.5787716666666665, details={'was_impossible': False}),
#  Prediction(uid=815, iid=9381, r_ui=2.0, est=3.766270054005965, details={'was_impossible': False}),
#  Prediction(uid=834, iid=10428, r_ui=2.0, est=3.6604082112562626, details={'was_impossible': False}),
#  Prediction(uid=857, iid=14302, r_ui=4.0, est=4.555301141654694, details={'was_impossible': False}),
#  Prediction(uid=906, iid=13493, r_ui=3.0, est=3.8907080855052545, details={'was_impossible': False}),
#  Prediction(uid=920, iid=11077, r_ui=5.0, est=3.718088553621474, details={'was_impossible': False}),
#  Prediction(uid=930, iid=15844, r_ui=4.0, est=4.147504205602966, details={'was_impossible': False}),
#  Prediction(uid=979, iid=9054, r_ui=4.0, est=3.380478398013303, details={'was_impossible': False}),
#  Prediction(uid=979, iid=14909, r_ui=4.0, est=3.5579265746813387, details={'was_impossible': False}),
#  Prediction(uid=981, iid=15425, r_ui=4.0, est=3.673451963962104, details={'was_impossible': False}),
#  Prediction(uid=1038, iid=7303, r_ui=5.0, est=3.9715957494892122, details={'was_impossible': False}),
#  Prediction(uid=1044, iid=6196, r_ui=4.0, est=4.049744602080828, details={'was_impossible': False}),
#  Prediction(uid=1067, iid=2913, r_ui=4.0, est=4.033241506376101, details={'was_impossible': False}),
#  Prediction(uid=1069, iid=14946, r_ui=4.0, est=4.077925077679736, details={'was_impossible': False}),
#  Prediction(uid=1070, iid=14358, r_ui=5.0, est=4.166090850516395, details={'was_impossible': False}),
#  Prediction(uid=1082, iid=2152, r_ui=4.0, est=3.399666404082501, details={'was_impossible': False}),
#  Prediction(uid=1086, iid=367, r_ui=3.0, est=2.8722682416303025, details={'was_impossible': False}),
#  Prediction(uid=1117, iid=15107, r_ui=4.0, est=3.9177322660576333, details={'was_impossible': False}),
#  Prediction(uid=1146, iid=5926, r_ui=3.0, est=4.080197608444559, details={'was_impossible': False}),
#  Prediction(uid=1146, iid=11443, r_ui=4.0, est=4.094703387757181, details={'was_impossible': False}),
#  Prediction(uid=1179, iid=12911, r_ui=5.0, est=3.5679170027077327, details={'was_impossible': False}),
#  Prediction(uid=1186, iid=13207, r_ui=5.0, est=3.9879924826852338, details={'was_impossible': False}),
#  Prediction(uid=1221, iid=4123, r_ui=3.0, est=3.3936977619158117, details={'was_impossible': False}),
#  Prediction(uid=1222, iid=9040, r_ui=1.0, est=3.6712485238617107, details={'was_impossible': False}),
#  Prediction(uid=1259, iid=9617, r_ui=3.0, est=3.504190917121886, details={'was_impossible': False}),
#  Prediction(uid=1276, iid=2913, r_ui=3.0, est=4.231638251785455, details={'was_impossible': False}),
#  Prediction(uid=1310, iid=8447, r_ui=4.0, est=4.485189732056268, details={'was_impossible': False}),
#  Prediction(uid=1323, iid=16997, r_ui=3.0, est=3.4650444677269254, details={'was_impossible': False}),
#  Prediction(uid=1327, iid=10928, r_ui=4.0, est=3.2855880553752397, details={'was_impossible': False}),
#  Prediction(uid=1331, iid=171, r_ui=3.0, est=3.93866052247362, details={'was_impossible': False}),
#  Prediction(uid=1333, iid=3938, r_ui=4.0, est=3.3480124756483027, details={'was_impossible': False}),
#  Prediction(uid=1353, iid=4356, r_ui=4.0, est=3.7406696322178834, details={'was_impossible': False}),
#  Prediction(uid=1355, iid=4237, r_ui=4.0, est=2.635806595019777, details={'was_impossible': False}),
#  Prediction(uid=1385, iid=4956, r_ui=3.0, est=3.7997020649363136, details={'was_impossible': False}),
#  Prediction(uid=1409, iid=4867, r_ui=3.0, est=3.3110249951321977, details={'was_impossible': False}),
#  Prediction(uid=1427, iid=6018, r_ui=4.0, est=3.1191088426580893, details={'was_impossible': False}),
#  Prediction(uid=1442, iid=4956, r_ui=5.0, est=3.9386673733453526, details={'was_impossible': False}),
#  Prediction(uid=1457, iid=3648, r_ui=5.0, est=3.616617219348626, details={'was_impossible': False}),
#  Prediction(uid=1457, iid=15064, r_ui=4.0, est=3.773167736370342, details={'was_impossible': False}),
#  Prediction(uid=1485, iid=9960, r_ui=1.0, est=3.6303755773170185, details={'was_impossible': False}),
#  Prediction(uid=1500, iid=16158, r_ui=3.0, est=3.9062656838448233, details={'was_impossible': False}),
#  Prediction(uid=1527, iid=3025, r_ui=3.0, est=3.3085431787751056, details={'was_impossible': False}),
#  Prediction(uid=1531, iid=6971, r_ui=3.0, est=3.960153686492117, details={'was_impossible': False}),
#  Prediction(uid=1533, iid=16181, r_ui=4.0, est=3.320231324527073, details={'was_impossible': False}),
#  Prediction(uid=1534, iid=6974, r_ui=5.0, est=4.449868694823532, details={'was_impossible': False}),
#  Prediction(uid=1588, iid=13433, r_ui=4.0, est=3.3257588513302014, details={'was_impossible': False}),
#  Prediction(uid=1590, iid=482, r_ui=5.0, est=3.7570902151121026, details={'was_impossible': False}),
#  Prediction(uid=1593, iid=14890, r_ui=4.0, est=3.247073048855724, details={'was_impossible': False}),
#  Prediction(uid=1606, iid=3159, r_ui=5.0, est=3.7295852362714146, details={'was_impossible': False}),
#  Prediction(uid=1611, iid=6255, r_ui=4.0, est=3.4240740813867996, details={'was_impossible': False}),
#  Prediction(uid=1626, iid=1202, r_ui=4.0, est=3.780867724843141, details={'was_impossible': False}),
#  Prediction(uid=1650, iid=15758, r_ui=5.0, est=4.2629648190342895, details={'was_impossible': False}),
#  Prediction(uid=1658, iid=11495, r_ui=3.0, est=3.467302524061549, details={'was_impossible': False}),
#  Prediction(uid=1664, iid=7645, r_ui=3.0, est=3.691250183556134, details={'was_impossible': False}),
#  Prediction(uid=1689, iid=14660, r_ui=3.0, est=3.3810372190611973, details={'was_impossible': False}),
#  Prediction(uid=1693, iid=12672, r_ui=4.0, est=3.8281294082851938, details={'was_impossible': False}),
#  Prediction(uid=1693, iid=15048, r_ui=4.0, est=3.759982559511076, details={'was_impossible': False}),
#  Prediction(uid=1701, iid=6908, r_ui=4.0, est=3.647710627592543, details={'was_impossible': False}),
#  Prediction(uid=1702, iid=6911, r_ui=4.0, est=3.37064621887168, details={'was_impossible': False}),
#  Prediction(uid=1715, iid=12305, r_ui=4.0, est=3.984937435638873, details={'was_impossible': False}),
#  Prediction(uid=1715, iid=3936, r_ui=3.0, est=3.280805715216502, details={'was_impossible': False}),
#  Prediction(uid=1717, iid=175, r_ui=4.0, est=4.168347074562666, details={'was_impossible': False}),
#  Prediction(uid=1723, iid=8569, r_ui=5.0, est=3.8519606670846005, details={'was_impossible': False}),
#  Prediction(uid=1730, iid=4786, r_ui=5.0, est=3.4938006527400405, details={'was_impossible': False}),
#  Prediction(uid=1734, iid=10300, r_ui=5.0, est=3.7206214091100156, details={'was_impossible': False}),
#  Prediction(uid=1738, iid=4577, r_ui=4.0, est=3.863728610125677, details={'was_impossible': False}),
#  Prediction(uid=1746, iid=10189, r_ui=5.0, est=3.364302351372634, details={'was_impossible': False}),
#  Prediction(uid=1791, iid=12714, r_ui=4.0, est=3.5179526134704586, details={'was_impossible': False}),
#  Prediction(uid=1809, iid=14780, r_ui=5.0, est=3.8281280576501224, details={'was_impossible': False}),
#  Prediction(uid=1811, iid=4570, r_ui=3.0, est=3.4561565240524197, details={'was_impossible': False}),
#  Prediction(uid=1830, iid=2981, r_ui=4.0, est=3.8093859655407734, details={'was_impossible': False}),
#  Prediction(uid=1846, iid=11314, r_ui=4.0, est=3.626822919256693, details={'was_impossible': False}),
#  Prediction(uid=1856, iid=1962, r_ui=4.0, est=3.529310237131151, details={'was_impossible': False}),
#  Prediction(uid=1871, iid=13031, r_ui=5.0, est=3.914198027862272, details={'was_impossible': False}),
#  Prediction(uid=1871, iid=15702, r_ui=3.0, est=3.825858058284336, details={'was_impossible': False}),
#  Prediction(uid=1888, iid=6386, r_ui=3.0, est=3.229621432584983, details={'was_impossible': False}),
#  Prediction(uid=1894, iid=16879, r_ui=5.0, est=3.600872906855854, details={'was_impossible': False}),
#  Prediction(uid=1897, iid=1754, r_ui=5.0, est=3.966094036280098, details={'was_impossible': False}),
#  Prediction(uid=1897, iid=10721, r_ui=2.0, est=3.12530265938613, details={'was_impossible': False}),
#  Prediction(uid=1900, iid=15997, r_ui=4.0, est=3.773890789375747, details={'was_impossible': False}),
#  Prediction(uid=1918, iid=15339, r_ui=4.0, est=3.0910278381578755, details={'was_impossible': False}),
#  Prediction(uid=1922, iid=13617, r_ui=3.0, est=3.5787716666666665, details={'was_impossible': False}),
#  Prediction(uid=1933, iid=6037, r_ui=3.0, est=4.021760178708042, details={'was_impossible': False}),
#  Prediction(uid=1947, iid=1962, r_ui=4.0, est=3.6811642631706496, details={'was_impossible': False}),
#  Prediction(uid=2000, iid=10928, r_ui=3.0, est=3.3351798346152655, details={'was_impossible': False}),
#  Prediction(uid=2007, iid=12244, r_ui=3.0, est=3.0802219023821427, details={'was_impossible': False}),
#  Prediction(uid=2024, iid=11279, r_ui=1.0, est=3.7893744351969945, details={'was_impossible': False}),
#  Prediction(uid=2027, iid=473, r_ui=4.0, est=4.090891855989438, details={'was_impossible': False}),
#  Prediction(uid=2050, iid=13923, r_ui=2.0, est=3.4672722818996826, details={'was_impossible': False}),
#  Prediction(uid=2052, iid=6972, r_ui=4.0, est=3.858081994062326, details={'was_impossible': False}),
#  Prediction(uid=2104, iid=2095, r_ui=3.0, est=3.442989507583151, details={'was_impossible': False}),
#  Prediction(uid=2110, iid=3879, r_ui=3.0, est=3.98001476170916, details={'was_impossible': False}),
#  Prediction(uid=2114, iid=2565, r_ui=4.0, est=3.313830995675684, details={'was_impossible': False}),
#  Prediction(uid=2122, iid=2922, r_ui=2.0, est=3.798847586911233, details={'was_impossible': False}),
#  Prediction(uid=2128, iid=5223, r_ui=3.0, est=3.4728287392611215, details={'was_impossible': False}),
#  Prediction(uid=2133, iid=4141, r_ui=4.0, est=3.0379244132938332, details={'was_impossible': False}),
#  Prediction(uid=2183, iid=11812, r_ui=5.0, est=4.16997452734447, details={'was_impossible': False}),
#  Prediction(uid=2190, iid=8782, r_ui=2.0, est=3.2752385851072794, details={'was_impossible': False}),
#  Prediction(uid=2196, iid=7617, r_ui=3.0, est=3.842195292980806, details={'was_impossible': False}),
#  Prediction(uid=2198, iid=1220, r_ui=5.0, est=4.064223623956824, details={'was_impossible': False}),
#  Prediction(uid=2203, iid=647, r_ui=4.0, est=3.7325768775019337, details={'was_impossible': False}),
#  Prediction(uid=2213, iid=7971, r_ui=3.0, est=3.872302853919186, details={'was_impossible': False}),
#  Prediction(uid=2213, iid=3684, r_ui=4.0, est=4.353791685569369, details={'was_impossible': False}),
#  Prediction(uid=2223, iid=11859, r_ui=4.0, est=3.7391446543119358, details={'was_impossible': False}),
#  Prediction(uid=2225, iid=5939, r_ui=3.0, est=3.29848391894255, details={'was_impossible': False}),
#  Prediction(uid=2233, iid=14241, r_ui=4.0, est=3.814713306997067, details={'was_impossible': False}),
#  Prediction(uid=2264, iid=8413, r_ui=4.0, est=3.3753082929503373, details={'was_impossible': False}),
#  Prediction(uid=2273, iid=4356, r_ui=4.0, est=3.621624822327372, details={'was_impossible': False}),
#  Prediction(uid=2280, iid=11022, r_ui=5.0, est=3.630710327068566, details={'was_impossible': False}),
#  Prediction(uid=2307, iid=12034, r_ui=5.0, est=4.161959530643222, details={'was_impossible': False}),
#  Prediction(uid=2338, iid=3938, r_ui=5.0, est=4.155964372573634, details={'was_impossible': False}),
#  Prediction(uid=2363, iid=1650, r_ui=5.0, est=3.8498800057452454, details={'was_impossible': False}),
#  Prediction(uid=2379, iid=3113, r_ui=2.0, est=3.2675795262557807, details={'was_impossible': False}),
#  Prediction(uid=2385, iid=3463, r_ui=5.0, est=3.8350179876884676, details={'was_impossible': False}),
#  Prediction(uid=2431, iid=11837, r_ui=2.0, est=3.1755878968426403, details={'was_impossible': False}),
#  Prediction(uid=2442, iid=14644, r_ui=3.0, est=2.5737964972414433, details={'was_impossible': False}),
#  Prediction(uid=2455, iid=11739, r_ui=3.0, est=3.585660052661118, details={'was_impossible': False}),
#  Prediction(uid=2467, iid=15124, r_ui=5.0, est=3.989235787734544, details={'was_impossible': False}),
#  Prediction(uid=2469, iid=12870, r_ui=5.0, est=4.273726486548692, details={'was_impossible': False}),
#  Prediction(uid=2555, iid=15361, r_ui=3.0, est=3.5691578863259137, details={'was_impossible': False}),
#  Prediction(uid=2662, iid=13081, r_ui=4.0, est=3.5514199580585695, details={'was_impossible': False}),
#  Prediction(uid=2678, iid=1650, r_ui=2.0, est=3.2630495860772566, details={'was_impossible': False}),
#  Prediction(uid=2693, iid=5033, r_ui=3.0, est=3.3213022879406187, details={'was_impossible': False}),
#  Prediction(uid=2705, iid=14859, r_ui=4.0, est=3.5425549110755084, details={'was_impossible': False}),
#  Prediction(uid=2724, iid=1289, r_ui=2.0, est=2.608168781926995, details={'was_impossible': False}),
#  Prediction(uid=2757, iid=30, r_ui=2.0, est=3.5544464592932004, details={'was_impossible': False}),
#  Prediction(uid=2757, iid=5732, r_ui=5.0, est=4.159371583884792, details={'was_impossible': False}),
#  Prediction(uid=2781, iid=12084, r_ui=3.0, est=3.194996263826631, details={'was_impossible': False}),
#  Prediction(uid=2787, iid=17330, r_ui=3.0, est=3.678204655128625, details={'was_impossible': False}),
#  Prediction(uid=2790, iid=406, r_ui=3.0, est=3.941688148576763, details={'was_impossible': False}),
#  Prediction(uid=2794, iid=5760, r_ui=4.0, est=4.411615030949462, details={'was_impossible': False}),
#  Prediction(uid=2807, iid=16707, r_ui=4.0, est=3.727284632214466, details={'was_impossible': False}),
#  Prediction(uid=2807, iid=1709, r_ui=3.0, est=3.605763954812513, details={'was_impossible': False}),
#  Prediction(uid=2878, iid=2186, r_ui=4.0, est=3.6126851754716816, details={'was_impossible': False}),
#  Prediction(uid=2892, iid=4656, r_ui=3.0, est=3.4371928838621115, details={'was_impossible': False}),
#  Prediction(uid=2900, iid=5922, r_ui=3.0, est=3.8641013866359533, details={'was_impossible': False}),
#  Prediction(uid=2900, iid=311, r_ui=3.0, est=3.673616042764278, details={'was_impossible': False}),
#  Prediction(uid=2905, iid=4953, r_ui=4.0, est=3.4593580654147633, details={'was_impossible': False}),
#  Prediction(uid=2942, iid=9340, r_ui=5.0, est=3.3998297894917866, details={'was_impossible': False}),
#  Prediction(uid=2960, iid=494, r_ui=4.0, est=4.1107244073308475, details={'was_impossible': False}),
#  Prediction(uid=2975, iid=8192, r_ui=5.0, est=3.6712546485866806, details={'was_impossible': False}),
#  Prediction(uid=2976, iid=1102, r_ui=4.0, est=3.5899800833091806, details={'was_impossible': False}),
#  Prediction(uid=2980, iid=14367, r_ui=4.0, est=3.7029434731989292, details={'was_impossible': False}),
#  Prediction(uid=2996, iid=7745, r_ui=5.0, est=3.9577593521482637, details={'was_impossible': False}),
#  Prediction(uid=3012, iid=4407, r_ui=3.0, est=4.05488076048135, details={'was_impossible': False}),
#  Prediction(uid=3018, iid=9048, r_ui=5.0, est=3.7026511628664083, details={'was_impossible': False}),
#  Prediction(uid=3039, iid=16952, r_ui=4.0, est=3.0548635984820454, details={'was_impossible': False}),
#  Prediction(uid=3040, iid=1692, r_ui=5.0, est=4.16115679798941, details={'was_impossible': False}),
#  Prediction(uid=3049, iid=12966, r_ui=4.0, est=3.6275454155977793, details={'was_impossible': False}),
#  Prediction(uid=3053, iid=11443, r_ui=4.0, est=3.9671626531142925, details={'was_impossible': False}),
#  Prediction(uid=3069, iid=1307, r_ui=1.0, est=3.4392971013882314, details={'was_impossible': False}),
#  Prediction(uid=3092, iid=11222, r_ui=3.0, est=4.251919470103519, details={'was_impossible': False}),
#  Prediction(uid=3094, iid=9828, r_ui=5.0, est=3.6899195861905554, details={'was_impossible': False}),
#  Prediction(uid=3097, iid=6615, r_ui=4.0, est=3.9651945845423593, details={'was_impossible': False}),
#  Prediction(uid=3101, iid=12206, r_ui=4.0, est=3.955494949326734, details={'was_impossible': False}),
#  Prediction(uid=3174, iid=2960, r_ui=1.0, est=2.369053084271666, details={'was_impossible': False}),
#  Prediction(uid=3184, iid=11337, r_ui=3.0, est=3.4718563459556058, details={'was_impossible': False}),
#  Prediction(uid=3186, iid=10730, r_ui=4.0, est=3.5382395996752747, details={'was_impossible': False}),
#  Prediction(uid=3232, iid=12778, r_ui=5.0, est=3.706928230562012, details={'was_impossible': False}),
#  Prediction(uid=3287, iid=4745, r_ui=3.0, est=3.2213180452843377, details={'was_impossible': False}),
#  Prediction(uid=3292, iid=5522, r_ui=3.0, est=2.9745187091131533, details={'was_impossible': False}),
#  Prediction(uid=3295, iid=12633, r_ui=4.0, est=3.378534249136316, details={'was_impossible': False}),
#  Prediction(uid=3300, iid=8764, r_ui=4.0, est=3.8044179887251217, details={'was_impossible': False}),
#  Prediction(uid=3321, iid=8448, r_ui=3.0, est=2.314770113611492, details={'was_impossible': False}),
#  Prediction(uid=3321, iid=5566, r_ui=3.0, est=2.685113903848964, details={'was_impossible': False}),
#  Prediction(uid=3321, iid=14131, r_ui=1.0, est=2.350428576062703, details={'was_impossible': False}),
#  Prediction(uid=3323, iid=15205, r_ui=2.0, est=3.322620698701478, details={'was_impossible': False}),
#  Prediction(uid=3363, iid=5137, r_ui=2.0, est=3.585167190767615, details={'was_impossible': False}),
#  Prediction(uid=3363, iid=4698, r_ui=4.0, est=3.137082353230252, details={'was_impossible': False}),
#  Prediction(uid=3373, iid=15788, r_ui=4.0, est=3.402841800137972, details={'was_impossible': False}),
#  Prediction(uid=3377, iid=3368, r_ui=4.0, est=3.567095707726914, details={'was_impossible': False}),
#  Prediction(uid=3379, iid=15285, r_ui=4.0, est=3.3180867788416153, details={'was_impossible': False}),
#  Prediction(uid=3386, iid=11722, r_ui=5.0, est=3.78362252762191, details={'was_impossible': False}),
#  Prediction(uid=3392, iid=13102, r_ui=5.0, est=3.3423636370651737, details={'was_impossible': False}),
#  Prediction(uid=3404, iid=14644, r_ui=4.0, est=2.6980878672010604, details={'was_impossible': False}),
#  Prediction(uid=3423, iid=15729, r_ui=4.0, est=3.842183345381203, details={'was_impossible': False}),
#  Prediction(uid=3432, iid=1220, r_ui=2.0, est=4.126936228195231, details={'was_impossible': False}),
#  Prediction(uid=3433, iid=15622, r_ui=1.0, est=3.523881565047232, details={'was_impossible': False}),
#  Prediction(uid=3456, iid=7509, r_ui=3.0, est=3.444821187972729, details={'was_impossible': False}),
#  Prediction(uid=3458, iid=6927, r_ui=3.0, est=3.0849711750683118, details={'was_impossible': False}),
#  Prediction(uid=3461, iid=12773, r_ui=4.0, est=3.3258052128501587, details={'was_impossible': False}),
#  Prediction(uid=3466, iid=14296, r_ui=3.0, est=3.9932737814729724, details={'was_impossible': False}),
#  Prediction(uid=3470, iid=1682, r_ui=3.0, est=3.57966957855, details={'was_impossible': False}),
#  Prediction(uid=3487, iid=15844, r_ui=4.0, est=4.0224815771861, details={'was_impossible': False}),
#  Prediction(uid=3492, iid=12582, r_ui=3.0, est=3.932810295824151, details={'was_impossible': False}),
#  Prediction(uid=3495, iid=14367, r_ui=4.0, est=3.628931367859956, details={'was_impossible': False}),
#  Prediction(uid=3498, iid=14550, r_ui=5.0, est=4.563060040043934, details={'was_impossible': False}),
#  Prediction(uid=3498, iid=12942, r_ui=4.0, est=3.747384387064342, details={'was_impossible': False}),
#  Prediction(uid=3502, iid=15582, r_ui=4.0, est=3.7376912240882194, details={'was_impossible': False}),
#  Prediction(uid=3521, iid=3523, r_ui=5.0, est=4.27371102324367, details={'was_impossible': False}),
#  Prediction(uid=3530, iid=4996, r_ui=4.0, est=3.5378113381153757, details={'was_impossible': False}),
#  Prediction(uid=3532, iid=13964, r_ui=4.0, est=3.845253764840083, details={'was_impossible': False}),
#  Prediction(uid=3549, iid=357, r_ui=3.0, est=3.2760922673000303, details={'was_impossible': False}),
#  Prediction(uid=3595, iid=15560, r_ui=2.0, est=3.1613209808026452, details={'was_impossible': False}),
#  Prediction(uid=3595, iid=17654, r_ui=1.0, est=2.76210512278255, details={'was_impossible': False}),
#  Prediction(uid=3602, iid=8512, r_ui=4.0, est=3.5824546888433044, details={'was_impossible': False}),
#  Prediction(uid=3604, iid=12311, r_ui=4.0, est=3.301298480702178, details={'was_impossible': False}),
#  Prediction(uid=3612, iid=588, r_ui=4.0, est=3.4206539706097723, details={'was_impossible': False}),
#  Prediction(uid=3621, iid=12355, r_ui=4.0, est=2.978320595136622, details={'was_impossible': False}),
#  Prediction(uid=3621, iid=5087, r_ui=5.0, est=3.615775866521748, details={'was_impossible': False}),
#  Prediction(uid=3694, iid=10123, r_ui=3.0, est=3.1843899216049834, details={'was_impossible': False}),
#  Prediction(uid=3715, iid=9545, r_ui=3.0, est=2.8921748600550994, details={'was_impossible': False}),
#  Prediction(uid=3718, iid=9768, r_ui=2.0, est=3.5717836054911536, details={'was_impossible': False}),
#  Prediction(uid=3728, iid=4266, r_ui=1.0, est=3.7800815308312634, details={'was_impossible': False}),
#  Prediction(uid=3742, iid=9548, r_ui=3.0, est=4.179836526747329, details={'was_impossible': False}),
#  Prediction(uid=3742, iid=9051, r_ui=3.0, est=3.9171865139252606, details={'was_impossible': False}),
#  Prediction(uid=3743, iid=2152, r_ui=2.0, est=3.489959585497935, details={'was_impossible': False}),
#  Prediction(uid=3764, iid=6716, r_ui=4.0, est=3.4651310609832504, details={'was_impossible': False}),
#  Prediction(uid=3767, iid=12084, r_ui=2.0, est=3.1088541730353847, details={'was_impossible': False}),
#  Prediction(uid=3777, iid=4801, r_ui=1.0, est=3.2305006744719917, details={'was_impossible': False}),
#  Prediction(uid=3786, iid=14050, r_ui=5.0, est=4.018444790949912, details={'was_impossible': False}),
#  Prediction(uid=3788, iid=15205, r_ui=3.0, est=3.309209135593298, details={'was_impossible': False}),
#  Prediction(uid=3798, iid=14042, r_ui=5.0, est=3.0960718469379698, details={'was_impossible': False}),
#  Prediction(uid=3802, iid=10078, r_ui=3.0, est=3.3245423692402807, details={'was_impossible': False}),
#  Prediction(uid=3826, iid=15472, r_ui=5.0, est=3.8863971898648417, details={'was_impossible': False}),
#  Prediction(uid=3870, iid=12232, r_ui=5.0, est=3.4516774050689953, details={'was_impossible': False}),
#  Prediction(uid=3871, iid=8644, r_ui=5.0, est=4.027012915490149, details={'was_impossible': False}),
#  Prediction(uid=3894, iid=7617, r_ui=4.0, est=3.9809308350846804, details={'was_impossible': False}),
#  Prediction(uid=3902, iid=14467, r_ui=4.0, est=2.341121712435437, details={'was_impossible': False}),
#  Prediction(uid=3906, iid=12003, r_ui=3.0, est=3.749109924917619, details={'was_impossible': False}),
#  Prediction(uid=3916, iid=12671, r_ui=4.0, est=4.2821253036827205, details={'was_impossible': False}),
#  Prediction(uid=3920, iid=15124, r_ui=5.0, est=3.966735593018937, details={'was_impossible': False}),
#  Prediction(uid=3921, iid=12672, r_ui=3.0, est=3.772547246633808, details={'was_impossible': False}),
#  Prediction(uid=3934, iid=13599, r_ui=4.0, est=3.3417027690774, details={'was_impossible': False}),
#  Prediction(uid=3952, iid=7391, r_ui=3.0, est=2.9166458610881913, details={'was_impossible': False}),
#  Prediction(uid=3978, iid=13651, r_ui=3.0, est=3.7049058349756723, details={'was_impossible': False}),
#  Prediction(uid=3984, iid=4345, r_ui=5.0, est=3.866266861881507, details={'was_impossible': False}),
#  Prediction(uid=3998, iid=14482, r_ui=5.0, est=4.7879431179781005, details={'was_impossible': False}),
#  Prediction(uid=3998, iid=9364, r_ui=5.0, est=3.9064861989483495, details={'was_impossible': False}),
#  Prediction(uid=4011, iid=10928, r_ui=1.0, est=3.4430362465801103, details={'was_impossible': False}),
#  Prediction(uid=4012, iid=11040, r_ui=5.0, est=4.0591755378826555, details={'was_impossible': False}),
#  Prediction(uid=4044, iid=13955, r_ui=3.0, est=3.352395657745135, details={'was_impossible': False}),
#  Prediction(uid=4057, iid=12828, r_ui=3.0, est=3.4866424017453626, details={'was_impossible': False}),
#  Prediction(uid=4059, iid=14712, r_ui=3.0, est=3.2142140148552607, details={'was_impossible': False}),
#  Prediction(uid=4066, iid=14454, r_ui=3.0, est=3.787312638479867, details={'was_impossible': False}),
#  Prediction(uid=4171, iid=6016, r_ui=5.0, est=3.328712167236837, details={'was_impossible': False}),
#  Prediction(uid=4184, iid=571, r_ui=4.0, est=4.068612155010066, details={'was_impossible': False}),
#  Prediction(uid=4212, iid=14538, r_ui=4.0, est=3.6540479899122436, details={'was_impossible': False}),
#  Prediction(uid=4229, iid=9257, r_ui=3.0, est=2.9966054206318136, details={'was_impossible': False}),
#  Prediction(uid=4247, iid=4577, r_ui=2.0, est=3.700248579254608, details={'was_impossible': False}),
#  Prediction(uid=4277, iid=8596, r_ui=4.0, est=4.119881204793777, details={'was_impossible': False}),
#  Prediction(uid=4298, iid=11337, r_ui=4.0, est=3.715322576321889, details={'was_impossible': False}),
#  Prediction(uid=4300, iid=1144, r_ui=4.0, est=4.099442117291542, details={'was_impossible': False}),
#  Prediction(uid=4306, iid=4972, r_ui=2.0, est=2.8935991490731943, details={'was_impossible': False}),
#  Prediction(uid=4313, iid=7155, r_ui=2.0, est=3.4798554516269378, details={'was_impossible': False}),
#  Prediction(uid=4314, iid=3151, r_ui=2.0, est=3.2203943608060013, details={'was_impossible': False}),
#  Prediction(uid=4315, iid=14584, r_ui=2.0, est=4.167797729406621, details={'was_impossible': False}),
#  Prediction(uid=4318, iid=111, r_ui=2.0, est=3.1697302740445323, details={'was_impossible': False}),
#  Prediction(uid=4326, iid=6068, r_ui=4.0, est=3.426467745722643, details={'was_impossible': False}),
#  Prediction(uid=4326, iid=1682, r_ui=4.0, est=3.7536291076991475, details={'was_impossible': False}),
#  Prediction(uid=4330, iid=6994, r_ui=3.0, est=3.682287893535966, details={'was_impossible': False}),
#  Prediction(uid=4347, iid=16954, r_ui=5.0, est=4.054060471317996, details={'was_impossible': False}),
#  Prediction(uid=4365, iid=6720, r_ui=5.0, est=3.939087969884026, details={'was_impossible': False}),
#  Prediction(uid=4374, iid=2352, r_ui=5.0, est=3.6299698729307477, details={'was_impossible': False}),
#  Prediction(uid=4398, iid=16596, r_ui=5.0, est=3.6999875047605597, details={'was_impossible': False}),
#  Prediction(uid=4409, iid=2751, r_ui=5.0, est=3.917359240093449, details={'was_impossible': False}),
#  Prediction(uid=4421, iid=16259, r_ui=3.0, est=3.1802910102998188, details={'was_impossible': False}),
#  Prediction(uid=4421, iid=6350, r_ui=2.0, est=3.452785038227139, details={'was_impossible': False}),
#  Prediction(uid=4421, iid=4697, r_ui=5.0, est=3.6802825453187986, details={'was_impossible': False}),
#  Prediction(uid=4422, iid=3541, r_ui=4.0, est=3.813608403772958, details={'was_impossible': False}),
#  Prediction(uid=4437, iid=3282, r_ui=2.0, est=3.4307484416717724, details={'was_impossible': False}),
#  Prediction(uid=4439, iid=17185, r_ui=1.0, est=3.559383554460919, details={'was_impossible': False}),
#  Prediction(uid=4451, iid=7879, r_ui=3.0, est=3.4543138107598974, details={'was_impossible': False}),
#  Prediction(uid=4460, iid=8334, r_ui=3.0, est=3.540278822486979, details={'was_impossible': False}),
#  Prediction(uid=4477, iid=3626, r_ui=3.0, est=3.4787073942693802, details={'was_impossible': False}),
#  Prediction(uid=4488, iid=3541, r_ui=2.0, est=3.6360935945748807, details={'was_impossible': False}),
#  Prediction(uid=4491, iid=7635, r_ui=4.0, est=2.9638991855811794, details={'was_impossible': False}),
#  Prediction(uid=4537, iid=334, r_ui=3.0, est=3.8680142832535855, details={'was_impossible': False}),
#  Prediction(uid=4545, iid=4432, r_ui=5.0, est=3.9231771853750033, details={'was_impossible': False}),
#  Prediction(uid=4576, iid=15955, r_ui=3.0, est=3.6819529632783072, details={'was_impossible': False}),
#  Prediction(uid=4580, iid=15894, r_ui=5.0, est=3.2908202110028535, details={'was_impossible': False}),
#  Prediction(uid=4581, iid=6134, r_ui=3.0, est=3.8092688893948736, details={'was_impossible': False}),
#  Prediction(uid=4597, iid=16721, r_ui=3.0, est=3.274076299766542, details={'was_impossible': False}),
#  Prediction(uid=4597, iid=4069, r_ui=2.0, est=3.2846003386070413, details={'was_impossible': False}),
#  Prediction(uid=4605, iid=3817, r_ui=5.0, est=3.887273936156008, details={'was_impossible': False}),
#  Prediction(uid=4606, iid=13384, r_ui=2.0, est=3.674372807533176, details={'was_impossible': False}),
#  Prediction(uid=4623, iid=175, r_ui=3.0, est=4.151785529972621, details={'was_impossible': False}),
#  Prediction(uid=4638, iid=16721, r_ui=4.0, est=3.7028086370143116, details={'was_impossible': False}),
#  Prediction(uid=4666, iid=8596, r_ui=5.0, est=4.293808082848657, details={'was_impossible': False}),
#  Prediction(uid=4667, iid=4402, r_ui=4.0, est=3.0707930006941373, details={'was_impossible': False}),
#  Prediction(uid=4679, iid=5561, r_ui=5.0, est=4.832516800495553, details={'was_impossible': False}),
#  Prediction(uid=4706, iid=1781, r_ui=4.0, est=3.9396667838188897, details={'was_impossible': False}),
#  Prediction(uid=4706, iid=13990, r_ui=4.0, est=3.558742422699647, details={'was_impossible': False}),
#  Prediction(uid=4739, iid=7286, r_ui=1.0, est=3.2879406064758823, details={'was_impossible': False}),
#  Prediction(uid=4753, iid=6736, r_ui=5.0, est=4.397591321222828, details={'was_impossible': False}),
#  Prediction(uid=4773, iid=5317, r_ui=4.0, est=3.225395259692658, details={'was_impossible': False}),
#  Prediction(uid=4783, iid=6552, r_ui=3.0, est=3.488510992370049, details={'was_impossible': False}),
#  Prediction(uid=4797, iid=1406, r_ui=5.0, est=3.3383270530818776, details={'was_impossible': False}),
#  Prediction(uid=4804, iid=2122, r_ui=1.0, est=3.6513439909285332, details={'was_impossible': False}),
#  Prediction(uid=4873, iid=13636, r_ui=3.0, est=3.7973104412964016, details={'was_impossible': False}),
#  Prediction(uid=4893, iid=6736, r_ui=3.0, est=4.234935016889383, details={'was_impossible': False}),
#  Prediction(uid=4894, iid=199, r_ui=4.0, est=4.0821556433578365, details={'was_impossible': False}),
#  Prediction(uid=4895, iid=9378, r_ui=5.0, est=4.051335670367578, details={'was_impossible': False}),
#  Prediction(uid=4905, iid=2186, r_ui=3.0, est=3.651033677437441, details={'was_impossible': False}),
#  Prediction(uid=4906, iid=14376, r_ui=3.0, est=3.6330790099050465, details={'was_impossible': False}),
#  Prediction(uid=4906, iid=17157, r_ui=4.0, est=4.5262575038750965, details={'was_impossible': False}),
#  Prediction(uid=4932, iid=17169, r_ui=3.0, est=3.7166854206498763, details={'was_impossible': False}),
#  Prediction(uid=4955, iid=12832, r_ui=5.0, est=3.769849236674363, details={'was_impossible': False}),
#  Prediction(uid=4977, iid=11931, r_ui=5.0, est=4.079110065339813, details={'was_impossible': False}),
#  Prediction(uid=4983, iid=257, r_ui=5.0, est=3.9383260898622665, details={'was_impossible': False}),
#  Prediction(uid=5004, iid=12911, r_ui=4.0, est=3.5494076479603565, details={'was_impossible': False}),
#  Prediction(uid=5017, iid=8432, r_ui=3.0, est=2.937294638789216, details={'was_impossible': False}),
#  Prediction(uid=5027, iid=8644, r_ui=2.0, est=4.077363235915227, details={'was_impossible': False}),
#  Prediction(uid=5082, iid=10451, r_ui=5.0, est=3.8998342414457703, details={'was_impossible': False}),
#  Prediction(uid=5092, iid=1905, r_ui=4.0, est=4.307189742050857, details={'was_impossible': False}),
#  Prediction(uid=5097, iid=2617, r_ui=5.0, est=3.10788670437994, details={'was_impossible': False}),
#  Prediction(uid=5107, iid=4302, r_ui=4.0, est=3.9558112020715797, details={'was_impossible': False}),
#  Prediction(uid=5109, iid=11421, r_ui=3.0, est=3.4809012824953713, details={'was_impossible': False}),
#  Prediction(uid=5202, iid=15107, r_ui=4.0, est=3.8931289664358757, details={'was_impossible': False}),
#  Prediction(uid=5225, iid=6029, r_ui=4.0, est=4.275249942399395, details={'was_impossible': False}),
#  Prediction(uid=5277, iid=5042, r_ui=4.0, est=3.5795213252581832, details={'was_impossible': False}),
#  Prediction(uid=5317, iid=8687, r_ui=3.0, est=3.583322853442025, details={'was_impossible': False}),
#  Prediction(uid=5356, iid=10117, r_ui=2.0, est=3.4388350188101797, details={'was_impossible': False}),
#  Prediction(uid=5399, iid=14454, r_ui=5.0, est=3.4722172794477992, details={'was_impossible': False}),
#  Prediction(uid=5412, iid=246, r_ui=3.0, est=3.25498208322461, details={'was_impossible': False}),
#  Prediction(uid=5430, iid=3958, r_ui=4.0, est=3.990377969152442, details={'was_impossible': False}),
#  Prediction(uid=5442, iid=7745, r_ui=5.0, est=3.8989213800837668, details={'was_impossible': False}),
#  Prediction(uid=5448, iid=8782, r_ui=5.0, est=3.5034309138494173, details={'was_impossible': False}),
#  Prediction(uid=5454, iid=5345, r_ui=4.0, est=3.558645203580777, details={'was_impossible': False}),
#  Prediction(uid=5496, iid=17104, r_ui=5.0, est=3.2210025985857342, details={'was_impossible': False}),
#  Prediction(uid=5498, iid=8636, r_ui=3.0, est=3.2187954512921957, details={'was_impossible': False}),
#  Prediction(uid=5519, iid=12582, r_ui=4.0, est=3.859506983639282, details={'was_impossible': False}),
#  Prediction(uid=5530, iid=3798, r_ui=5.0, est=4.574105603717356, details={'was_impossible': False}),
#  Prediction(uid=5549, iid=17085, r_ui=5.0, est=4.533291601709288, details={'was_impossible': False}),
#  Prediction(uid=5568, iid=3675, r_ui=3.0, est=3.0258230564702417, details={'was_impossible': False}),
#  Prediction(uid=5569, iid=16452, r_ui=3.0, est=4.172492703453587, details={'was_impossible': False}),
#  Prediction(uid=5575, iid=8099, r_ui=4.0, est=3.060165292958453, details={'was_impossible': False}),
#  Prediction(uid=5596, iid=12206, r_ui=5.0, est=3.955494949326734, details={'was_impossible': False}),
#  Prediction(uid=5600, iid=9156, r_ui=3.0, est=3.550158305176507, details={'was_impossible': False}),
#  Prediction(uid=5612, iid=3315, r_ui=3.0, est=3.8682388752596277, details={'was_impossible': False}),
#  Prediction(uid=5618, iid=14856, r_ui=4.0, est=3.9425086743454907, details={'was_impossible': False}),
#  Prediction(uid=5650, iid=3153, r_ui=1.0, est=3.990824025280427, details={'was_impossible': False}),
#  Prediction(uid=5650, iid=16954, r_ui=5.0, est=4.135028808421927, details={'was_impossible': False}),
#  Prediction(uid=5652, iid=15132, r_ui=4.0, est=3.2697594308567917, details={'was_impossible': False}),
#  Prediction(uid=5665, iid=13647, r_ui=4.0, est=3.943647760713702, details={'was_impossible': False}),
#  Prediction(uid=5668, iid=16901, r_ui=5.0, est=3.462184078118839, details={'was_impossible': False}),
#  Prediction(uid=5696, iid=12399, r_ui=5.0, est=3.7517338652170693, details={'was_impossible': False}),
#  Prediction(uid=5720, iid=9617, r_ui=3.0, est=3.4559537702763055, details={'was_impossible': False}),
#  Prediction(uid=5727, iid=2800, r_ui=3.0, est=3.7975909785023916, details={'was_impossible': False}),
#  Prediction(uid=5739, iid=15205, r_ui=4.0, est=3.3989610806861834, details={'was_impossible': False}),
#  Prediction(uid=5758, iid=15063, r_ui=3.0, est=3.290266960643131, details={'was_impossible': False}),
#  Prediction(uid=5762, iid=9532, r_ui=4.0, est=4.1150763486313675, details={'was_impossible': False}),
#  Prediction(uid=5771, iid=14240, r_ui=5.0, est=4.1820873370658695, details={'was_impossible': False}),
#  Prediction(uid=5771, iid=11378, r_ui=5.0, est=3.8513741273287474, details={'was_impossible': False}),
#  Prediction(uid=5775, iid=5317, r_ui=2.0, est=3.285770579720547, details={'was_impossible': False}),
#  Prediction(uid=5823, iid=15712, r_ui=4.0, est=3.166166478142337, details={'was_impossible': False}),
#  Prediction(uid=5827, iid=15267, r_ui=5.0, est=4.187165511025506, details={'was_impossible': False}),
#  Prediction(uid=5841, iid=16859, r_ui=2.0, est=3.4887955010454097, details={'was_impossible': False}),
#  Prediction(uid=5856, iid=15844, r_ui=3.0, est=3.9321475469519704, details={'was_impossible': False}),
#  Prediction(uid=5858, iid=1719, r_ui=2.0, est=3.091218923199941, details={'was_impossible': False}),
#  Prediction(uid=5878, iid=3254, r_ui=3.0, est=2.9389046547893862, details={'was_impossible': False}),
#  Prediction(uid=5889, iid=4266, r_ui=3.0, est=3.666104825413045, details={'was_impossible': False}),
#  Prediction(uid=5889, iid=2314, r_ui=3.0, est=3.3396111508534654, details={'was_impossible': False}),
#  Prediction(uid=5915, iid=30, r_ui=3.0, est=3.7033247544599095, details={'was_impossible': False}),
#  Prediction(uid=5916, iid=3364, r_ui=4.0, est=3.732041473490302, details={'was_impossible': False}),
#  Prediction(uid=5917, iid=15815, r_ui=1.0, est=3.0695347191103197, details={'was_impossible': False}),
#  Prediction(uid=5931, iid=16139, r_ui=2.0, est=3.427902610798782, details={'was_impossible': False}),
#  Prediction(uid=5945, iid=4356, r_ui=3.0, est=3.3814550582425924, details={'was_impossible': False}),
#  Prediction(uid=5951, iid=4472, r_ui=1.0, est=3.61269614420325, details={'was_impossible': False}),
#  Prediction(uid=5977, iid=13493, r_ui=4.0, est=3.7502771459516757, details={'was_impossible': False}),
#  Prediction(uid=5977, iid=4919, r_ui=5.0, est=3.940479357266799, details={'was_impossible': False}),
#  Prediction(uid=5980, iid=4060, r_ui=2.0, est=3.5991211544395534, details={'was_impossible': False}),
#  Prediction(uid=5980, iid=1561, r_ui=5.0, est=3.5941485258372925, details={'was_impossible': False}),
#  Prediction(uid=5987, iid=6972, r_ui=3.0, est=3.759156431376085, details={'was_impossible': False}),
#  Prediction(uid=5989, iid=1180, r_ui=4.0, est=3.9444380140601183, details={'was_impossible': False}),
#  Prediction(uid=5994, iid=6117, r_ui=4.0, est=3.903283827368099, details={'was_impossible': False}),
#  Prediction(uid=6013, iid=12918, r_ui=5.0, est=3.9729024409225855, details={'was_impossible': False}),
#  Prediction(uid=6037, iid=15609, r_ui=5.0, est=4.248919591898083, details={'was_impossible': False}),
#  Prediction(uid=6048, iid=5401, r_ui=1.0, est=2.9280286239425557, details={'was_impossible': False}),
#  Prediction(uid=6056, iid=15578, r_ui=4.0, est=3.6469242890764364, details={'was_impossible': False}),
#  Prediction(uid=6057, iid=12546, r_ui=4.0, est=3.2747077332546, details={'was_impossible': False}),
#  Prediction(uid=6062, iid=11283, r_ui=4.0, est=4.242865883665936, details={'was_impossible': False}),
#  Prediction(uid=6065, iid=2009, r_ui=4.0, est=3.3907224368620623, details={'was_impossible': False}),
#  Prediction(uid=6071, iid=9330, r_ui=5.0, est=4.312804052159881, details={'was_impossible': False}),
#  Prediction(uid=6082, iid=8181, r_ui=2.0, est=3.4309369697478647, details={'was_impossible': False}),
#  Prediction(uid=6092, iid=16572, r_ui=4.0, est=3.3265281560192226, details={'was_impossible': False}),
#  Prediction(uid=6096, iid=13555, r_ui=2.0, est=2.8048148082598257, details={'was_impossible': False}),
#  Prediction(uid=6110, iid=14718, r_ui=1.0, est=2.888124450845287, details={'was_impossible': False}),
#  Prediction(uid=6138, iid=2612, r_ui=5.0, est=3.758401561346693, details={'was_impossible': False}),
#  Prediction(uid=6161, iid=1790, r_ui=4.0, est=3.9185773011878777, details={'was_impossible': False}),
#  Prediction(uid=6172, iid=4972, r_ui=1.0, est=3.4741580334535267, details={'was_impossible': False}),
#  Prediction(uid=6173, iid=10820, r_ui=4.0, est=4.070386695068014, details={'was_impossible': False}),
#  Prediction(uid=6177, iid=10294, r_ui=4.0, est=3.332866635301554, details={'was_impossible': False}),
#  Prediction(uid=6178, iid=668, r_ui=5.0, est=4.326199173516597, details={'was_impossible': False}),
#  Prediction(uid=6186, iid=10550, r_ui=3.0, est=3.65801533754297, details={'was_impossible': False}),
#  Prediction(uid=6206, iid=3478, r_ui=4.0, est=3.887124087211422, details={'was_impossible': False}),
#  Prediction(uid=6231, iid=2862, r_ui=5.0, est=4.382419254869689, details={'was_impossible': False}),
#  Prediction(uid=6265, iid=15755, r_ui=4.0, est=3.821348709445506, details={'was_impossible': False}),
#  Prediction(uid=6268, iid=5732, r_ui=4.0, est=4.337328006855804, details={'was_impossible': False}),
#  Prediction(uid=6304, iid=2409, r_ui=2.0, est=2.832561121245626, details={'was_impossible': False}),
#  Prediction(uid=6310, iid=14313, r_ui=4.0, est=3.9035206173047206, details={'was_impossible': False}),
#  Prediction(uid=6319, iid=5528, r_ui=3.0, est=3.5561323331676276, details={'was_impossible': False}),
#  Prediction(uid=6368, iid=16782, r_ui=3.0, est=3.654123640448239, details={'was_impossible': False}),
#  Prediction(uid=6368, iid=6287, r_ui=4.0, est=4.021451803833277, details={'was_impossible': False}),
#  Prediction(uid=6369, iid=7230, r_ui=5.0, est=4.781490685400196, details={'was_impossible': False}),
#  Prediction(uid=6373, iid=16913, r_ui=5.0, est=3.7428801879544995, details={'was_impossible': False}),
#  Prediction(uid=6381, iid=17174, r_ui=3.0, est=3.831661305252718, details={'was_impossible': False}),
#  Prediction(uid=6401, iid=13622, r_ui=3.0, est=3.9874898768830973, details={'was_impossible': False}),
#  Prediction(uid=6402, iid=10607, r_ui=4.0, est=4.002346218359708, details={'was_impossible': False}),
#  Prediction(uid=6416, iid=1905, r_ui=5.0, est=4.3106806362159915, details={'was_impossible': False}),
#  Prediction(uid=6427, iid=6615, r_ui=5.0, est=4.16928477795703, details={'was_impossible': False}),
#  Prediction(uid=6435, iid=1324, r_ui=5.0, est=4.14331788924636, details={'was_impossible': False}),
#  Prediction(uid=6444, iid=11173, r_ui=4.0, est=3.3996237387291517, details={'was_impossible': False}),
#  Prediction(uid=6455, iid=14313, r_ui=5.0, est=3.4825255337188112, details={'was_impossible': False}),
#  Prediction(uid=6457, iid=16222, r_ui=4.0, est=3.5562624471964916, details={'was_impossible': False}),
#  Prediction(uid=6460, iid=14624, r_ui=5.0, est=3.370708597733745, details={'was_impossible': False}),
#  Prediction(uid=6460, iid=3782, r_ui=4.0, est=3.0541771296351015, details={'was_impossible': False}),
#  Prediction(uid=6463, iid=290, r_ui=5.0, est=3.506304368165465, details={'was_impossible': False}),
#  Prediction(uid=6483, iid=11013, r_ui=4.0, est=3.1864512340895814, details={'was_impossible': False}),
#  Prediction(uid=6485, iid=1295, r_ui=4.0, est=3.8269097714125095, details={'was_impossible': False}),
#  Prediction(uid=6488, iid=6042, r_ui=3.0, est=3.085406800093699, details={'was_impossible': False}),
#  Prediction(uid=6500, iid=14410, r_ui=3.0, est=3.3518535992713905, details={'was_impossible': False}),
#  Prediction(uid=6504, iid=11047, r_ui=5.0, est=3.8562834588024026, details={'was_impossible': False}),
#  Prediction(uid=6514, iid=15582, r_ui=5.0, est=3.627167834527017, details={'was_impossible': False}),
#  Prediction(uid=6514, iid=7624, r_ui=5.0, est=3.8476207668680225, details={'was_impossible': False}),
#  Prediction(uid=6529, iid=14545, r_ui=5.0, est=3.5621586974070754, details={'was_impossible': False}),
#  Prediction(uid=6534, iid=6464, r_ui=3.0, est=3.5787771217816267, details={'was_impossible': False}),
#  Prediction(uid=6544, iid=1193, r_ui=4.0, est=3.599487231785558, details={'was_impossible': False}),
# ...
#  Prediction(uid=11144, iid=17495, r_ui=4.0, est=2.9501799038469625, details={'was_impossible': False}),
#  Prediction(uid=11166, iid=2986, r_ui=2.0, est=3.3275214992070503, details={'was_impossible': False}),
#  Prediction(uid=11169, iid=10921, r_ui=3.0, est=2.7095514412018904, details={'was_impossible': False}),
#  Prediction(uid=11176, iid=13081, r_ui=3.0, est=3.655892263318005, details={'was_impossible': False}),
#  Prediction(uid=11186, iid=9392, r_ui=4.0, est=3.6966887659566297, details={'was_impossible': False}),
#  Prediction(uid=11203, iid=10418, r_ui=5.0, est=4.585711725947168, details={'was_impossible': False}),
#  Prediction(uid=11205, iid=3715, r_ui=2.0, est=3.4087742541660595, details={'was_impossible': False}),
#  Prediction(uid=11212, iid=14869, r_ui=2.0, est=3.9459958023949016, details={'was_impossible': False}),
#  Prediction(uid=11215, iid=2457, r_ui=4.0, est=3.6517013857218728, details={'was_impossible': False}),
#  Prediction(uid=11234, iid=6994, r_ui=5.0, est=3.6934348588076706, details={'was_impossible': False}),
#  Prediction(uid=11267, iid=6378, r_ui=4.0, est=3.8583698675757576, details={'was_impossible': False}),
#  Prediction(uid=11278, iid=11182, r_ui=2.0, est=3.5318887462049053, details={'was_impossible': False}),
#  Prediction(uid=11310, iid=17175, r_ui=3.0, est=3.2184512928717153, details={'was_impossible': False}),
#  Prediction(uid=11318, iid=6552, r_ui=5.0, est=3.199431802283815, details={'was_impossible': False}),
#  Prediction(uid=11318, iid=17129, r_ui=5.0, est=3.6365993148865488, details={'was_impossible': False}),
#  Prediction(uid=11325, iid=17586, r_ui=4.0, est=2.303080746186563, details={'was_impossible': False}),
#  Prediction(uid=11334, iid=6235, r_ui=2.0, est=3.8433447512179004, details={'was_impossible': False}),
#  Prediction(uid=11340, iid=13580, r_ui=4.0, est=3.814297319179832, details={'was_impossible': False}),
#  Prediction(uid=11356, iid=6720, r_ui=4.0, est=3.8527960168259203, details={'was_impossible': False}),
#  Prediction(uid=11368, iid=6692, r_ui=5.0, est=3.577243471184615, details={'was_impossible': False}),
#  Prediction(uid=11374, iid=4227, r_ui=5.0, est=3.7390743188424644, details={'was_impossible': False}),
#  Prediction(uid=11376, iid=6119, r_ui=3.0, est=2.906433663678392, details={'was_impossible': False}),
#  Prediction(uid=11393, iid=14644, r_ui=2.0, est=2.6289414953005164, details={'was_impossible': False}),
#  Prediction(uid=11398, iid=17628, r_ui=5.0, est=4.030171665778791, details={'was_impossible': False}),
#  Prediction(uid=11400, iid=2342, r_ui=3.0, est=3.7110443632727517, details={'was_impossible': False}),
#  Prediction(uid=11409, iid=11165, r_ui=5.0, est=3.866206459244268, details={'was_impossible': False}),
#  Prediction(uid=11415, iid=12785, r_ui=3.0, est=4.010983530748279, details={'was_impossible': False}),
#  Prediction(uid=11424, iid=13641, r_ui=2.0, est=3.6054308676011435, details={'was_impossible': False}),
#  Prediction(uid=11430, iid=15820, r_ui=4.0, est=3.7951457046494, details={'was_impossible': False}),
#  Prediction(uid=11430, iid=11183, r_ui=4.0, est=4.273012659327405, details={'was_impossible': False}),
#  Prediction(uid=11430, iid=9756, r_ui=5.0, est=3.914803588282003, details={'was_impossible': False}),
#  Prediction(uid=11452, iid=57, r_ui=4.0, est=3.8454026581429632, details={'was_impossible': False}),
#  Prediction(uid=11456, iid=12034, r_ui=5.0, est=4.096734082755627, details={'was_impossible': False}),
#  Prediction(uid=11462, iid=12493, r_ui=3.0, est=3.7076761801690648, details={'was_impossible': False}),
#  Prediction(uid=11472, iid=16871, r_ui=4.0, est=3.3853045119226666, details={'was_impossible': False}),
#  Prediction(uid=11491, iid=4883, r_ui=5.0, est=3.6748497164722616, details={'was_impossible': False}),
#  Prediction(uid=11540, iid=12184, r_ui=5.0, est=4.45061170005265, details={'was_impossible': False}),
#  Prediction(uid=11547, iid=6428, r_ui=5.0, est=4.271013715144407, details={'was_impossible': False}),
#  Prediction(uid=11568, iid=5345, r_ui=3.0, est=3.5506247350036775, details={'was_impossible': False}),
#  Prediction(uid=11571, iid=1956, r_ui=5.0, est=4.105286160101312, details={'was_impossible': False}),
#  Prediction(uid=11583, iid=12966, r_ui=4.0, est=3.476728895223506, details={'was_impossible': False}),
#  Prediction(uid=11583, iid=5462, r_ui=4.0, est=3.082945792096859, details={'was_impossible': False}),
#  Prediction(uid=11589, iid=12974, r_ui=4.0, est=3.335124151525336, details={'was_impossible': False}),
#  Prediction(uid=11591, iid=14240, r_ui=5.0, est=4.445407266570484, details={'was_impossible': False}),
#  Prediction(uid=11594, iid=17299, r_ui=4.0, est=3.7096763048313153, details={'was_impossible': False}),
#  Prediction(uid=11598, iid=11198, r_ui=2.0, est=3.7289939826616054, details={'was_impossible': False}),
#  Prediction(uid=11598, iid=6287, r_ui=3.0, est=3.9530921666544927, details={'was_impossible': False}),
#  Prediction(uid=11627, iid=15813, r_ui=2.0, est=3.0242145676066396, details={'was_impossible': False}),
#  Prediction(uid=11656, iid=12470, r_ui=4.0, est=3.591444406443774, details={'was_impossible': False}),
#  Prediction(uid=11676, iid=4570, r_ui=3.0, est=3.4207274702139956, details={'was_impossible': False}),
#  Prediction(uid=11690, iid=4256, r_ui=5.0, est=3.6348632430296672, details={'was_impossible': False}),
#  Prediction(uid=11690, iid=2391, r_ui=4.0, est=3.29217361595599, details={'was_impossible': False}),
#  Prediction(uid=11701, iid=10358, r_ui=2.0, est=3.0974869371626803, details={'was_impossible': False}),
#  Prediction(uid=11711, iid=11961, r_ui=4.0, est=4.156926128961534, details={'was_impossible': False}),
#  Prediction(uid=11717, iid=14538, r_ui=4.0, est=3.669778812844002, details={'was_impossible': False}),
#  Prediction(uid=11731, iid=5317, r_ui=4.0, est=3.3462802726625087, details={'was_impossible': False}),
#  Prediction(uid=11734, iid=15844, r_ui=5.0, est=4.031324820031879, details={'was_impossible': False}),
#  Prediction(uid=11760, iid=1542, r_ui=4.0, est=3.9030545492819506, details={'was_impossible': False}),
#  Prediction(uid=11764, iid=11443, r_ui=4.0, est=3.8495846414413966, details={'was_impossible': False}),
#  Prediction(uid=11765, iid=11337, r_ui=4.0, est=3.7976393563926614, details={'was_impossible': False}),
#  Prediction(uid=11795, iid=17482, r_ui=5.0, est=3.550728717653058, details={'was_impossible': False}),
#  Prediction(uid=11796, iid=10820, r_ui=5.0, est=3.742379949644743, details={'was_impossible': False}),
#  Prediction(uid=11826, iid=6223, r_ui=3.0, est=3.3871662370632007, details={'was_impossible': False}),
#  Prediction(uid=11857, iid=16922, r_ui=3.0, est=3.4624873098602915, details={'was_impossible': False}),
#  Prediction(uid=11865, iid=12792, r_ui=5.0, est=4.309959505319886, details={'was_impossible': False}),
#  Prediction(uid=11866, iid=2554, r_ui=4.0, est=3.5455141972173787, details={'was_impossible': False}),
#  Prediction(uid=11875, iid=11802, r_ui=5.0, est=4.181423931330121, details={'was_impossible': False}),
#  Prediction(uid=11878, iid=8782, r_ui=1.0, est=3.4010458175951297, details={'was_impossible': False}),
#  Prediction(uid=11942, iid=4656, r_ui=1.0, est=3.7319845955159234, details={'was_impossible': False}),
#  Prediction(uid=11997, iid=10947, r_ui=4.0, est=4.223688465386318, details={'was_impossible': False}),
#  Prediction(uid=12007, iid=3798, r_ui=5.0, est=4.190679061827226, details={'was_impossible': False}),
#  Prediction(uid=12020, iid=3047, r_ui=3.0, est=3.4339743096958992, details={'was_impossible': False}),
#  Prediction(uid=12036, iid=334, r_ui=1.0, est=3.7244159974555826, details={'was_impossible': False}),
#  Prediction(uid=12052, iid=12232, r_ui=3.0, est=3.448228600206509, details={'was_impossible': False}),
#  Prediction(uid=12079, iid=16452, r_ui=4.0, est=3.9569685984971716, details={'was_impossible': False}),
#  Prediction(uid=12110, iid=3274, r_ui=3.0, est=3.956844910166094, details={'was_impossible': False}),
#  Prediction(uid=12137, iid=15070, r_ui=5.0, est=4.202899069319484, details={'was_impossible': False}),
#  Prediction(uid=12138, iid=17308, r_ui=4.0, est=3.025428670832408, details={'was_impossible': False}),
#  Prediction(uid=12147, iid=3640, r_ui=2.0, est=2.9328551032363666, details={'was_impossible': False}),
#  Prediction(uid=12168, iid=11994, r_ui=4.0, est=3.8929468818189883, details={'was_impossible': False}),
#  Prediction(uid=12199, iid=4745, r_ui=1.0, est=3.2213180452843377, details={'was_impossible': False}),
#  Prediction(uid=12207, iid=10168, r_ui=4.0, est=3.0246376429794632, details={'was_impossible': False}),
#  Prediction(uid=12216, iid=438, r_ui=5.0, est=3.278046537834407, details={'was_impossible': False}),
#  Prediction(uid=12224, iid=16406, r_ui=3.0, est=3.716406248708075, details={'was_impossible': False}),
#  Prediction(uid=12234, iid=13359, r_ui=3.0, est=3.608563685340593, details={'was_impossible': False}),
#  Prediction(uid=12234, iid=12966, r_ui=5.0, est=3.54909989284616, details={'was_impossible': False}),
#  Prediction(uid=12244, iid=2152, r_ui=3.0, est=3.263088196764797, details={'was_impossible': False}),
#  Prediction(uid=12253, iid=8393, r_ui=4.0, est=3.905592289018764, details={'was_impossible': False}),
#  Prediction(uid=12253, iid=9051, r_ui=5.0, est=4.007578884927927, details={'was_impossible': False}),
#  Prediction(uid=12254, iid=10241, r_ui=4.0, est=3.464388193527763, details={'was_impossible': False}),
#  Prediction(uid=12266, iid=3148, r_ui=3.0, est=3.3588041532662785, details={'was_impossible': False}),
#  Prediction(uid=12275, iid=16075, r_ui=4.0, est=3.799409923101251, details={'was_impossible': False}),
#  Prediction(uid=12330, iid=4262, r_ui=4.0, est=3.9942593510894557, details={'was_impossible': False}),
#  Prediction(uid=12379, iid=9254, r_ui=4.0, est=3.8646160398889706, details={'was_impossible': False}),
#  Prediction(uid=12416, iid=7624, r_ui=5.0, est=4.044774533158752, details={'was_impossible': False}),
#  Prediction(uid=12430, iid=12220, r_ui=3.0, est=3.306591133310103, details={'was_impossible': False}),
#  Prediction(uid=12449, iid=5814, r_ui=3.0, est=2.93965731570228, details={'was_impossible': False}),
#  Prediction(uid=12451, iid=3500, r_ui=5.0, est=3.833997415156742, details={'was_impossible': False}),
#  Prediction(uid=12475, iid=13251, r_ui=5.0, est=3.6341340397030564, details={'was_impossible': False}),
#  Prediction(uid=12477, iid=11314, r_ui=3.0, est=3.883558704782193, details={'was_impossible': False}),
#  Prediction(uid=12487, iid=4432, r_ui=4.0, est=3.863769974565629, details={'was_impossible': False}),
#  Prediction(uid=12537, iid=17085, r_ui=5.0, est=4.533781204035632, details={'was_impossible': False}),
#  Prediction(uid=12542, iid=7230, r_ui=5.0, est=4.745216568741767, details={'was_impossible': False}),
#  Prediction(uid=12559, iid=6860, r_ui=4.0, est=3.6044036229593113, details={'was_impossible': False}),
#  Prediction(uid=12573, iid=14750, r_ui=4.0, est=4.211341178607344, details={'was_impossible': False}),
#  Prediction(uid=12580, iid=5708, r_ui=4.0, est=3.26557896117386, details={'was_impossible': False}),
#  Prediction(uid=12649, iid=313, r_ui=2.0, est=3.607848422821542, details={'was_impossible': False}),
#  Prediction(uid=12650, iid=7739, r_ui=3.0, est=2.9704994967408815, details={'was_impossible': False}),
#  Prediction(uid=12666, iid=16765, r_ui=5.0, est=3.770376018476127, details={'was_impossible': False}),
#  Prediction(uid=12684, iid=13342, r_ui=4.0, est=3.188882011756638, details={'was_impossible': False}),
#  Prediction(uid=12708, iid=14454, r_ui=5.0, est=3.8758355210315365, details={'was_impossible': False}),
#  Prediction(uid=12708, iid=2431, r_ui=3.0, est=3.7344371336130755, details={'was_impossible': False}),
#  Prediction(uid=12765, iid=8637, r_ui=3.0, est=4.062613076943356, details={'was_impossible': False}),
#  Prediction(uid=12770, iid=7391, r_ui=4.0, est=2.912445430258038, details={'was_impossible': False}),
#  Prediction(uid=12771, iid=6931, r_ui=2.0, est=3.441425596360729, details={'was_impossible': False}),
#  Prediction(uid=12789, iid=7879, r_ui=5.0, est=3.4950801353349563, details={'was_impossible': False}),
#  Prediction(uid=12798, iid=7563, r_ui=4.0, est=3.151469484215275, details={'was_impossible': False}),
#  Prediction(uid=12801, iid=13728, r_ui=4.0, est=4.159855180437192, details={'was_impossible': False}),
#  Prediction(uid=12804, iid=17295, r_ui=5.0, est=3.2965174633013565, details={'was_impossible': False}),
#  Prediction(uid=12809, iid=4227, r_ui=4.0, est=3.6743901300258077, details={'was_impossible': False}),
#  Prediction(uid=12812, iid=13955, r_ui=3.0, est=3.2760856868795094, details={'was_impossible': False}),
#  Prediction(uid=12812, iid=3925, r_ui=4.0, est=3.57201773612584, details={'was_impossible': False}),
#  Prediction(uid=12812, iid=16365, r_ui=3.0, est=3.7021037357873605, details={'was_impossible': False}),
#  Prediction(uid=12813, iid=473, r_ui=3.0, est=4.106602391795429, details={'was_impossible': False}),
#  Prediction(uid=12840, iid=7701, r_ui=5.0, est=3.817201045919058, details={'was_impossible': False}),
#  Prediction(uid=12869, iid=8181, r_ui=4.0, est=3.3241062630031375, details={'was_impossible': False}),
#  Prediction(uid=12870, iid=7131, r_ui=4.0, est=3.4452864973319075, details={'was_impossible': False}),
#  Prediction(uid=12876, iid=3427, r_ui=5.0, est=3.5877107662061327, details={'was_impossible': False}),
#  Prediction(uid=12904, iid=13955, r_ui=4.0, est=3.4101078280887394, details={'was_impossible': False}),
#  Prediction(uid=12912, iid=1939, r_ui=4.0, est=3.8456726925887335, details={'was_impossible': False}),
#  Prediction(uid=12914, iid=5154, r_ui=4.0, est=3.5106375361810485, details={'was_impossible': False}),
#  Prediction(uid=12920, iid=11607, r_ui=5.0, est=4.236091608986329, details={'was_impossible': False}),
#  Prediction(uid=12969, iid=5317, r_ui=5.0, est=3.211417322794423, details={'was_impossible': False}),
#  Prediction(uid=12986, iid=11451, r_ui=3.0, est=3.971917966479023, details={'was_impossible': False}),
#  Prediction(uid=12987, iid=11089, r_ui=5.0, est=4.504792500294874, details={'was_impossible': False}),
#  Prediction(uid=12990, iid=13636, r_ui=1.0, est=3.5729710206279677, details={'was_impossible': False}),
#  Prediction(uid=13003, iid=9188, r_ui=4.0, est=3.3186563453339017, details={'was_impossible': False}),
#  Prediction(uid=13004, iid=2803, r_ui=5.0, est=4.40048793144212, details={'was_impossible': False}),
#  Prediction(uid=13013, iid=10240, r_ui=4.0, est=2.53804426696273, details={'was_impossible': False}),
#  Prediction(uid=13017, iid=1501, r_ui=4.0, est=3.434865825892672, details={'was_impossible': False}),
#  Prediction(uid=13021, iid=14671, r_ui=4.0, est=4.274101029066851, details={'was_impossible': False}),
#  Prediction(uid=13058, iid=1000, r_ui=3.0, est=3.7069029910177287, details={'was_impossible': False}),
#  Prediction(uid=13061, iid=12870, r_ui=4.0, est=4.430267227113031, details={'was_impossible': False}),
#  Prediction(uid=13069, iid=14086, r_ui=1.0, est=3.5821146586428867, details={'was_impossible': False}),
#  Prediction(uid=13070, iid=10042, r_ui=4.0, est=4.581729963941522, details={'was_impossible': False}),
#  Prediction(uid=13074, iid=14550, r_ui=5.0, est=4.576054376325879, details={'was_impossible': False}),
#  Prediction(uid=13076, iid=9205, r_ui=3.0, est=3.2162257056263055, details={'was_impossible': False}),
#  Prediction(uid=13085, iid=13830, r_ui=5.0, est=3.598688766229654, details={'was_impossible': False}),
#  Prediction(uid=13090, iid=13651, r_ui=3.0, est=3.5384102575198786, details={'was_impossible': False}),
#  Prediction(uid=13125, iid=4883, r_ui=2.0, est=3.6125854810748024, details={'was_impossible': False}),
#  Prediction(uid=13128, iid=8687, r_ui=2.0, est=3.9287950513690513, details={'was_impossible': False}),
#  Prediction(uid=13141, iid=16302, r_ui=4.0, est=4.551942281483064, details={'was_impossible': False}),
#  Prediction(uid=13157, iid=14691, r_ui=4.0, est=4.115949276653631, details={'was_impossible': False}),
#  Prediction(uid=13183, iid=6555, r_ui=3.0, est=3.440171261813876, details={'was_impossible': False}),
#  Prediction(uid=13197, iid=1665, r_ui=4.0, est=3.1836786434708593, details={'was_impossible': False}),
#  ...]

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.7935
# 0.7935138946573231

# %%
accuracy.rmse(predictions, verbose=True)
# Out:
# RMSE: 0.9922
# 0.9921980884454588

# %% [markdown]
# # First Simple Model

# %%
#instance of SVD algorithm, fit using training set
svd = SVD(random_state=1)
svd.fit(train_sr)

#predicting based on validation set
preds = svd.test(test_sr)

# %%
#mae
accuracy.mae(preds)
# Out:
# MAE:  0.8052
# 0.8051670661228093

# %%
#rmse score
accuracy.rmse(preds)
# Out:
# RMSE: 1.0067
# 1.006748871084584

# %%
crossval = cross_validate(svd, train_data, measures=['MAE','RMSE'], cv=5, verbose=True)
# Out:
# Evaluating MAE, RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# MAE (testset)     0.7972  0.7987  0.7969  0.7991  0.7977  0.7979  0.0008
# RMSE (testset)    0.9982  1.0001  0.9970  0.9997  0.9990  0.9988  0.0011
# Fit time          5.80    5.99    6.03    6.02    6.02    5.97    0.09
# Test time         0.71    0.66    1.15    0.67    0.67    0.77    0.19

# %% [markdown]
# # Tuning First Simple Model
#
# This model performed slightly worse. Tuning model below using GridSearchCV and RandomizedSearchCV
#
# **Note:** From my research, I have learned that SVD models are very sensitive and prone to overfitting. ***Because this is an academic exercise, I am taking the time to test minute changes.***
#
# ### Gridsearch SVD Model

# %%
#gridsearch params
param_grid = {'n_factors':[50, 100, 120, 150, 200], 
              #default 100, quality of training set preds tends to grow as n grows
              'n_epochs': [20, 30, 40, 60], #default 20
              'lr_all': [0.005, 0.008, 0.01, 0.125], 
              #learning rate all params, default .005
              'reg_all': [0.02, 0.08, 0.1, 0.12, 0.16]} 
                #reg term for all params, default .02


#default measures = mae and rmse
#default cv = 5
#refit = false
gridsearch = GridSearchCV(SVD,
                  param_grid,
                  n_jobs = -1)

gridsearch.fit(train_data)

print(gridsearch.best_score['rmse'])
print(gridsearch.best_params['rmse'])
# Out:
# 0.9893126323300756
# {'n_factors': 50, 'n_epochs': 30, 'lr_all': 0.005, 'reg_all': 0.12}

# %%
algo = SVD(n_factors= 50, n_epochs= 30, lr_all= 0.005, reg_all= 0.12)
algo.fit(train_sr)
preds_final = algo.test(test_sr)

accuracy.rmse(preds_final)
accuracy.mae(preds_final)
# Out:
# RMSE: 0.9927
# MAE:  0.7948
# 0.7947657472013869

# %%
preds_holdout = algo.test(ho_sr)

accuracy.rmse(preds_holdout)
accuracy.mae(preds_holdout)
# Out:
# RMSE: 0.9977
# MAE:  0.8001
# 0.800059632300629

# %% [markdown]
# ### RandomizedSearchCV

# %%
rs = RandomizedSearchCV(SVD,
                        param_grid,
                       n_jobs = -1,
                       random_state=1) #defined above
#n_iter default = 10
#cv = 5
rs.fit(train_data)

print(gridsearch.best_score['rmse'])
print(gridsearch.best_params['rmse'])

# %%
# %notify

# %% [markdown]
# references:
# https://towardsdatascience.com/build-a-recommender-system-yelp-rating-prediction-example-collaborative-filtering-28a6e48a8cc
#
# surprise tutorialL
# https://towardsdatascience.com/building-and-testing-recommender-systems-with-surprise-step-by-step-d4ba702ef80b
